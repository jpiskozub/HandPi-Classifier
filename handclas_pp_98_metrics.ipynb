# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime



#import psycopg as psql

import configparser

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay


from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras import layers, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
import tensorflow as tf


from keras.regularizers import l2


from tensorflow.keras.utils import timeseries_dataset_from_array, normalize



config = configparser.ConfigParser()
config.read('config.ini')



devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(devices[0], True)
# Out:
# 2023-05-04 10:29:31.801852: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 10:29:31.875763: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-04 10:29:32.213635: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/
# 2023-05-04 10:29:32.213698: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/
# 2023-05-04 10:29:32.213701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-05-04 10:29:32.544553: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:32.550388: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:32.550417: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
ADC_channels = ['P1_1', 'P1_2', 'P2_1', 'P2_2', 'P3_1', 'P3_2', 'P4_1', 'P4_2', 'P5_1', 'P5_2']
IMU_channels = ['Euler_x', 'Euler_y', 'Euler_z', 'Acc_x', 'Acc_y', 'Acc_z']

sign_types = ['static', 'dynamic']
sign_types_dict = {'a': sign_types[0],
                   'ą': sign_types[1],
                   'b': sign_types[0],
                   'c': sign_types[0],
                   'ć': sign_types[1],
                   'ch': sign_types[1],
                   'cz': sign_types[1],
                   'd': sign_types[1],
                   'e': sign_types[0],
                   'ę': sign_types[1],
                   'f': sign_types[1],
                   'g': sign_types[1],
                   'h': sign_types[1],
                   'i': sign_types[0],
                   'j': sign_types[1],
                   'k': sign_types[1],
                   'l': sign_types[0],
                   'ł': sign_types[1],
                   'm': sign_types[0],
                   'n': sign_types[0],
                   'ń': sign_types[1],
                   'o': sign_types[0],
                   'ó': sign_types[1],
                   'p': sign_types[0],
                   'r': sign_types[0],
                   'rz': sign_types[1],
                   's': sign_types[0],
                   'ś': sign_types[1],
                   'sz': sign_types[1],
                   't': sign_types[0],
                   'u': sign_types[0],
                   'w': sign_types[0],
                   'y': sign_types[0],
                   'z': sign_types[1],
                   'ź': sign_types[1],
                   'ż': sign_types[1]}


SAMPLE_SIZE = 75

# %%
# LOADING
#df = pd.read_csv("G:\Git_repos\HandPi-ETL\gesty.csv")
# df = pd.read_csv('G:/Git_repos/HandPi-ETL/gesty_pp_aug.csv')
# df = pd.concat([df, pd.read_csv('G:/Git_repos/HandPi-ETL/gesty_pp.csv')], ignore_index=True )
df = pd.read_csv("/mnt/g/Git_repos/HandPi-ETL/gesty_pp.csv")
df = df[df['exam_id'] != ('tt',15)]

# %%
# ADDING AUGMENTED DATA
adf = pd.read_csv("/mnt/g/Git_repos/HandPi-ETL/gesty_pp_aug.csv")
adf.columns = df.columns[0:19]
df = pd.concat([df, adf ], ignore_index=True)

# %%
# FEATURE SELECTION
# droplist = ['P1_1', 'P2_1', 'P3_1', 'P4_1', 'P4_2', 'P5_1', 'P5_2'] + IMU_channels
# df = df.drop(droplist, axis=1)

# %%
# DATA CURING
df.fillna(method='backfill', inplace=True)
print(f'NaN containment:{df.isnull().any()}')
num_rows = df.shape[0] // SAMPLE_SIZE
num_ts = num_rows*SAMPLE_SIZE
# Out:
# NaN containment:exam_id       False
# P1_1          False
# P1_2          False
# P2_1          False
# P2_2          False
# P3_1          False
# P3_2          False
# P4_1          False
# P4_2          False
# P5_1          False
# P5_2          False
# Euler_x       False
# Euler_y       False
# Euler_z       False
# Acc_x         False
# Acc_y         False
# Acc_z         False
# sign          False
# timestamp     False
# gesture_id     True
# dtype: bool

# %%
# DATA AND LABELS
x = df.iloc[:num_ts,1:(df.shape[1]-3)].values
y = df['sign'].values

num_classes = len(np.unique(y))

# %%
# CONVERTING & ENCODING LABELS
Y_resh = np.reshape(y,(num_ts//SAMPLE_SIZE,SAMPLE_SIZE,1))
Y = Y_resh[:,1,:]

#Y_enc = [int.from_bytes(char.encode('utf-8'), byteorder="big") for char in Y ]

Y_enc = pd.get_dummies(Y.flatten())



X_resh = np.reshape(x,(num_ts//SAMPLE_SIZE, SAMPLE_SIZE, x.shape[1]))

# %%
# SPLITTING

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(X_resh, Y_enc)

test_acc_list =[]
train_acc_list = []
y_int_pred_class = []
y_int_test_class = []


for i, (train_index, test_index) in enumerate(skf.split(X_resh, Y)):

    X_test1 = X_resh[test_index]
    X_train = X_resh[train_index]
    Y_train = Y_enc.iloc[train_index]
    Y_test1 =Y_enc.iloc[test_index]

    X_test, X_val, Y_test, Y_val = train_test_split(X_test1, Y_test1, test_size=0.2, random_state=0, stratify=Y_test1)

    print(X_train.shape[0])
    print(X_test.shape[0])
    print(X_val.shape[0])
    print(Y_train.shape[0])
    print(Y_test.shape[0])
    print(Y_val.shape[0])

    train_dataset = (X_train, Y_train)
    test_dataset = (X_test, Y_test)
    val_dataset = (X_val, Y_val)



#train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
#test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

## MODEL CONSTANTS
    LAYERS = np.dot(1,[75, 75, 75])                # number of units in hidden and output layers
    M_TRAIN = X_train.shape[0]                     # number of training examples (2D)
    M_TEST = X_test.shape[0]                       # number of test examples (2D),full=X_test.shape[0]
    N = X_train.shape[2]                           # number of features
    BATCH = 256                                    # batch size
    EPOCH = 60                                   # number of epochs
    LR = 2e-3                          # learning rate of the gradient descent
    LAMBD = 3e-2                         # lambda in L2 regularizaion
    DP = 0.5                           # dropout rate
    RDP = 0                           # recurrent dropout rate

    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

    checkpoint = ModelCheckpoint(filepath=log_dir+'/models/'+'model.{epoch:02d}-{val_categorical_accuracy:.2f}.hdf5',
                                 monitor='val_categorical_accuracy',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=False,
                                 mode='max')

    lr_decay = ReduceLROnPlateau(monitor='loss',
                                 patience=1, verbose=1,
                                 factor=0.5, min_lr=1e-6)

    early_stop = EarlyStopping(monitor='categorical_accuracy', min_delta=0,
                               patience=7, verbose=1, mode='auto',
                               baseline=0, restore_best_weights=True)

    initial_learning_rate = LR
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=100000,
        decay_rate=0.96,
        staircase=True)


    # MODEL DEFINITION
    model = Sequential()
    model.add(layers.Input(shape=(X_train.shape[1], X_train.shape[2])))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[0],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=True, return_state=False,
                          stateful=False, unroll=False))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[1],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=True, return_state=False,
                          stateful=False, unroll=False))
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[2],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=False, return_state=False,
                          stateful=False, unroll=False))
    
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(36, activation='softmax'))

    opt = optimizers.Adam(learning_rate=LR,  clipnorm=1.)



    # MODEL COMPILATION
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['categorical_accuracy'])

    print(model.summary())


    # TRAINING
    history = model.fit(X_train, Y_train, epochs=EPOCH, batch_size=BATCH,
                        shuffle=True,validation_data=val_dataset,
                        callbacks=[
                                    early_stop
                                    ,lr_decay
                                    ,checkpoint
                                    ,tensorboard_callback]
                        )






    # EVALUATION
    # train_loss, train_acc = model.evaluate(X_train, Y_train,
    #                                        batch_size=M_TRAIN, verbose=0)
    test_loss, test_acc = model.evaluate(X_test, Y_test,
                                         batch_size=M_TEST, verbose=0)

    test_acc_list.append(test_acc)
    #train_acc_list.append(train_acc)

    # ACCURACY AND LOSS PLOTS

    print(max(history.history['val_categorical_accuracy']))

    plt.plot(history.history['val_loss'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('Model loss and accuracy')
    plt.ylabel('Loss/Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Loss', 'Accuracy'], loc='upper left')
    plt.show()


    y_pred = model.predict(X_test)
    
    
    y_int_pred_class.append(np.argmax(y_pred, axis=1))
    y_int_test_class.append(np.argmax(Y_test.values, axis=1))

    # CONFUSION MATRIX
oh_dict=dict(zip([i for i in range(num_classes)],list(sign_types_dict.keys())))
# Out:
# 57566
# 11513
# 2879
# 57566
# 11513
# 2879
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 75, 16)           64
#  ormalization)
#
#  conv1d (Conv1D)             (None, 73, 64)            3136
#
#  batch_normalization_1 (Batc  (None, 73, 64)           256
#  hNormalization)
#
#  gru (GRU)                   (None, 73, 75)            31725
#
#  batch_normalization_2 (Batc  (None, 73, 75)           300
#  hNormalization)
#
#  conv1d_1 (Conv1D)           (None, 71, 64)            14464
#
#  batch_normalization_3 (Batc  (None, 71, 64)           256
#  hNormalization)
#
#  gru_1 (GRU)                 (None, 71, 75)            31725
#
#  conv1d_2 (Conv1D)           (None, 69, 64)            14464
#
#  batch_normalization_4 (Batc  (None, 69, 64)           256
#  hNormalization)
#
#  gru_2 (GRU)                 (None, 75)                31725
#
#  batch_normalization_5 (Batc  (None, 75)               300
#  hNormalization)
#
#  dense (Dense)               (None, 36)                2736
#
# =================================================================
# Total params: 131,407
# Trainable params: 130,691
# Non-trainable params: 716
# _________________________________________________________________
# 2023-05-04 10:29:48.381927: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 10:29:48.383640: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.383674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.383688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.722489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.722540: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.722544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-04 10:29:48.722564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-04 10:29:48.722588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5909 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# None
# Epoch 1/60
# 2023-05-04 10:29:52.662188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-05-04 10:29:53.023968: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-05-04 10:29:54.259941: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x40a1c8c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-04 10:29:54.259989: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2023-05-04 10:29:54.263736: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-04 10:29:54.347493: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-05-04 10:29:54.368291: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-05-04 10:29:54.935118: W tensorflow/tsl/framework/bfc_allocator.cc:360] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 225/225 [==============================] - ETA: 0s - loss: 3.9149 - categorical_accuracy: 0.4703
# Epoch 1: val_categorical_accuracy improved from -inf to 0.02779, saving model to logs/fit/20230504-102948/models/model.01-0.03.hdf5
# 225/225 [==============================] - 171s 732ms/step - loss: 3.9149 - categorical_accuracy: 0.4703 - val_loss: 5.3031 - val_categorical_accuracy: 0.0278 - lr: 0.0020
# Epoch 2/60
# 225/225 [==============================] - ETA: 0s - loss: 0.4567 - categorical_accuracy: 0.9462
# Epoch 2: val_categorical_accuracy improved from 0.02779 to 0.50573, saving model to logs/fit/20230504-102948/models/model.02-0.51.hdf5
# 225/225 [==============================] - 165s 733ms/step - loss: 0.4567 - categorical_accuracy: 0.9462 - val_loss: 1.8614 - val_categorical_accuracy: 0.5057 - lr: 0.0020
# Epoch 3/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2619 - categorical_accuracy: 0.9741
# Epoch 3: val_categorical_accuracy improved from 0.50573 to 0.77249, saving model to logs/fit/20230504-102948/models/model.03-0.77.hdf5
# 225/225 [==============================] - 164s 730ms/step - loss: 0.2619 - categorical_accuracy: 0.9741 - val_loss: 0.9647 - val_categorical_accuracy: 0.7725 - lr: 0.0020
# Epoch 4/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2133 - categorical_accuracy: 0.9796
# Epoch 4: val_categorical_accuracy improved from 0.77249 to 0.87114, saving model to logs/fit/20230504-102948/models/model.04-0.87.hdf5
# 225/225 [==============================] - 164s 729ms/step - loss: 0.2133 - categorical_accuracy: 0.9796 - val_loss: 0.6343 - val_categorical_accuracy: 0.8711 - lr: 0.0020
# Epoch 5/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1919 - categorical_accuracy: 0.9822
# Epoch 5: val_categorical_accuracy did not improve from 0.87114
# 225/225 [==============================] - 162s 719ms/step - loss: 0.1919 - categorical_accuracy: 0.9822 - val_loss: 0.9254 - val_categorical_accuracy: 0.8305 - lr: 0.0020
# Epoch 6/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1819 - categorical_accuracy: 0.9826
# Epoch 6: val_categorical_accuracy did not improve from 0.87114
# 225/225 [==============================] - 164s 730ms/step - loss: 0.1819 - categorical_accuracy: 0.9826 - val_loss: 0.9081 - val_categorical_accuracy: 0.8222 - lr: 0.0020
# Epoch 7/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1727 - categorical_accuracy: 0.9836
# Epoch 7: val_categorical_accuracy did not improve from 0.87114
# 225/225 [==============================] - 164s 727ms/step - loss: 0.1727 - categorical_accuracy: 0.9836 - val_loss: 1.1752 - val_categorical_accuracy: 0.7860 - lr: 0.0020
# Epoch 8/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1635 - categorical_accuracy: 0.9852
# Epoch 8: val_categorical_accuracy did not improve from 0.87114
# 225/225 [==============================] - 162s 720ms/step - loss: 0.1635 - categorical_accuracy: 0.9852 - val_loss: 0.9461 - val_categorical_accuracy: 0.8038 - lr: 0.0020
# Epoch 9/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1449 - categorical_accuracy: 0.9876
# Epoch 9: val_categorical_accuracy improved from 0.87114 to 0.88711, saving model to logs/fit/20230504-102948/models/model.09-0.89.hdf5
# 225/225 [==============================] - 160s 712ms/step - loss: 0.1449 - categorical_accuracy: 0.9876 - val_loss: 0.7667 - val_categorical_accuracy: 0.8871 - lr: 0.0020
# Epoch 10/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1471 - categorical_accuracy: 0.9877
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 10: val_categorical_accuracy did not improve from 0.88711
# 225/225 [==============================] - 161s 716ms/step - loss: 0.1471 - categorical_accuracy: 0.9877 - val_loss: 0.7868 - val_categorical_accuracy: 0.8791 - lr: 0.0020
# Epoch 11/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0826 - categorical_accuracy: 0.9947
# Epoch 11: val_categorical_accuracy did not improve from 0.88711
# 225/225 [==============================] - 159s 709ms/step - loss: 0.0826 - categorical_accuracy: 0.9947 - val_loss: 0.9560 - val_categorical_accuracy: 0.8524 - lr: 0.0010
# Epoch 12/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0802 - categorical_accuracy: 0.9932
# Epoch 12: val_categorical_accuracy improved from 0.88711 to 0.89024, saving model to logs/fit/20230504-102948/models/model.12-0.89.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0802 - categorical_accuracy: 0.9932 - val_loss: 0.7637 - val_categorical_accuracy: 0.8902 - lr: 0.0010
# Epoch 13/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0738 - categorical_accuracy: 0.9940
# Epoch 13: val_categorical_accuracy improved from 0.89024 to 0.89337, saving model to logs/fit/20230504-102948/models/model.13-0.89.hdf5
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0738 - categorical_accuracy: 0.9940 - val_loss: 0.8781 - val_categorical_accuracy: 0.8934 - lr: 0.0010
# Epoch 14/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0753 - categorical_accuracy: 0.9931
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: val_categorical_accuracy did not improve from 0.89337
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0753 - categorical_accuracy: 0.9931 - val_loss: 0.7394 - val_categorical_accuracy: 0.8854 - lr: 0.0010
# Epoch 15/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0485 - categorical_accuracy: 0.9970
# Epoch 15: val_categorical_accuracy improved from 0.89337 to 0.91282, saving model to logs/fit/20230504-102948/models/model.15-0.91.hdf5
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0485 - categorical_accuracy: 0.9970 - val_loss: 0.5860 - val_categorical_accuracy: 0.9128 - lr: 5.0000e-04
# Epoch 16/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0444 - categorical_accuracy: 0.9965
# Epoch 16: val_categorical_accuracy improved from 0.91282 to 0.93470, saving model to logs/fit/20230504-102948/models/model.16-0.93.hdf5
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0444 - categorical_accuracy: 0.9965 - val_loss: 0.3990 - val_categorical_accuracy: 0.9347 - lr: 5.0000e-04
# Epoch 17/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0410 - categorical_accuracy: 0.9969
# Epoch 17: val_categorical_accuracy did not improve from 0.93470
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0410 - categorical_accuracy: 0.9969 - val_loss: 0.6321 - val_categorical_accuracy: 0.8767 - lr: 5.0000e-04
# Epoch 18/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0403 - categorical_accuracy: 0.9968
# Epoch 18: val_categorical_accuracy did not improve from 0.93470
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0403 - categorical_accuracy: 0.9968 - val_loss: 0.8939 - val_categorical_accuracy: 0.8829 - lr: 5.0000e-04
# Epoch 19/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0423 - categorical_accuracy: 0.9962
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_categorical_accuracy did not improve from 0.93470
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0423 - categorical_accuracy: 0.9962 - val_loss: 0.6979 - val_categorical_accuracy: 0.8930 - lr: 5.0000e-04
# Epoch 20/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0312 - categorical_accuracy: 0.9985
# Epoch 20: val_categorical_accuracy did not improve from 0.93470
# 225/225 [==============================] - 158s 702ms/step - loss: 0.0312 - categorical_accuracy: 0.9985 - val_loss: 0.4636 - val_categorical_accuracy: 0.9076 - lr: 2.5000e-04
# Epoch 21/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0288 - categorical_accuracy: 0.9981
# Epoch 21: val_categorical_accuracy did not improve from 0.93470
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0288 - categorical_accuracy: 0.9981 - val_loss: 0.6346 - val_categorical_accuracy: 0.9177 - lr: 2.5000e-04
# Epoch 22/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0264 - categorical_accuracy: 0.9983
# Epoch 22: val_categorical_accuracy improved from 0.93470 to 0.93609, saving model to logs/fit/20230504-102948/models/model.22-0.94.hdf5
# 225/225 [==============================] - 158s 704ms/step - loss: 0.0264 - categorical_accuracy: 0.9983 - val_loss: 0.5577 - val_categorical_accuracy: 0.9361 - lr: 2.5000e-04
# Epoch 23/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0276 - categorical_accuracy: 0.9977
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 23: val_categorical_accuracy did not improve from 0.93609
# 225/225 [==============================] - 158s 704ms/step - loss: 0.0276 - categorical_accuracy: 0.9977 - val_loss: 0.6171 - val_categorical_accuracy: 0.9243 - lr: 2.5000e-04
# Epoch 24/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0219 - categorical_accuracy: 0.9991
# Epoch 24: val_categorical_accuracy did not improve from 0.93609
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0219 - categorical_accuracy: 0.9991 - val_loss: 0.5280 - val_categorical_accuracy: 0.9191 - lr: 1.2500e-04
# Epoch 25/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0198 - categorical_accuracy: 0.9991
# Epoch 25: val_categorical_accuracy did not improve from 0.93609
# 225/225 [==============================] - 157s 699ms/step - loss: 0.0198 - categorical_accuracy: 0.9991 - val_loss: 0.6185 - val_categorical_accuracy: 0.9194 - lr: 1.2500e-04
# Epoch 26/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0197 - categorical_accuracy: 0.9988
# Epoch 26: val_categorical_accuracy did not improve from 0.93609
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0197 - categorical_accuracy: 0.9988 - val_loss: 0.5110 - val_categorical_accuracy: 0.9357 - lr: 1.2500e-04
# Epoch 27/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0194 - categorical_accuracy: 0.9987
# Epoch 27: val_categorical_accuracy improved from 0.93609 to 0.93887, saving model to logs/fit/20230504-102948/models/model.27-0.94.hdf5
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0194 - categorical_accuracy: 0.9987 - val_loss: 0.4710 - val_categorical_accuracy: 0.9389 - lr: 1.2500e-04
# Epoch 28/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0189 - categorical_accuracy: 0.9988
# Epoch 28: val_categorical_accuracy did not improve from 0.93887
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0189 - categorical_accuracy: 0.9988 - val_loss: 0.3694 - val_categorical_accuracy: 0.9305 - lr: 1.2500e-04
# Epoch 29/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 0.9989
# Epoch 29: val_categorical_accuracy improved from 0.93887 to 0.94130, saving model to logs/fit/20230504-102948/models/model.29-0.94.hdf5
# 225/225 [==============================] - 158s 702ms/step - loss: 0.0188 - categorical_accuracy: 0.9989 - val_loss: 0.5170 - val_categorical_accuracy: 0.9413 - lr: 1.2500e-04
# Epoch 30/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0187 - categorical_accuracy: 0.9986
# Epoch 30: val_categorical_accuracy did not improve from 0.94130
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0187 - categorical_accuracy: 0.9986 - val_loss: 0.5283 - val_categorical_accuracy: 0.9347 - lr: 1.2500e-04
# Epoch 31/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0179 - categorical_accuracy: 0.9989Restoring model weights from the end of the best epoch: 24.
#
# Epoch 31: val_categorical_accuracy did not improve from 0.94130
# 225/225 [==============================] - 158s 702ms/step - loss: 0.0179 - categorical_accuracy: 0.9989 - val_loss: 0.4293 - val_categorical_accuracy: 0.9364 - lr: 1.2500e-04
# Epoch 31: early stopping
# 0.9412990808486938
# 360/360 [==============================] - 14s 38ms/step
# 57566
# 11513
# 2879
# 57566
# 11513
# 2879
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_6 (Batc  (None, 75, 16)           64
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 73, 64)            3136
#
#  batch_normalization_7 (Batc  (None, 73, 64)           256
#  hNormalization)
#
#  gru_3 (GRU)                 (None, 73, 75)            31725
#
#  batch_normalization_8 (Batc  (None, 73, 75)           300
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 71, 64)            14464
#
#  batch_normalization_9 (Batc  (None, 71, 64)           256
#  hNormalization)
#
#  gru_4 (GRU)                 (None, 71, 75)            31725
#
#  conv1d_5 (Conv1D)           (None, 69, 64)            14464
#
#  batch_normalization_10 (Bat  (None, 69, 64)           256
#  chNormalization)
#
#  gru_5 (GRU)                 (None, 75)                31725
#
#  batch_normalization_11 (Bat  (None, 75)               300
#  chNormalization)
#
#  dense_1 (Dense)             (None, 36)                2736
#
# =================================================================
# Total params: 131,407
# Trainable params: 130,691
# Non-trainable params: 716
# _________________________________________________________________
# None
# Epoch 1/60
# 225/225 [==============================] - ETA: 0s - loss: 3.9229 - categorical_accuracy: 0.4761
# Epoch 1: val_categorical_accuracy improved from -inf to 0.02952, saving model to logs/fit/20230504-115255/models/model.01-0.03.hdf5
# 225/225 [==============================] - 164s 710ms/step - loss: 3.9229 - categorical_accuracy: 0.4761 - val_loss: 5.0146 - val_categorical_accuracy: 0.0295 - lr: 0.0020
# Epoch 2/60
# 225/225 [==============================] - ETA: 0s - loss: 0.4437 - categorical_accuracy: 0.9496
# Epoch 2: val_categorical_accuracy improved from 0.02952 to 0.72629, saving model to logs/fit/20230504-115255/models/model.02-0.73.hdf5
# 225/225 [==============================] - 160s 712ms/step - loss: 0.4437 - categorical_accuracy: 0.9496 - val_loss: 1.1999 - val_categorical_accuracy: 0.7263 - lr: 0.0020
# Epoch 3/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2688 - categorical_accuracy: 0.9728
# Epoch 3: val_categorical_accuracy improved from 0.72629 to 0.90379, saving model to logs/fit/20230504-115255/models/model.03-0.90.hdf5
# 225/225 [==============================] - 158s 702ms/step - loss: 0.2688 - categorical_accuracy: 0.9728 - val_loss: 0.4729 - val_categorical_accuracy: 0.9038 - lr: 0.0020
# Epoch 4/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2151 - categorical_accuracy: 0.9805
# Epoch 4: val_categorical_accuracy did not improve from 0.90379
# 225/225 [==============================] - 160s 710ms/step - loss: 0.2151 - categorical_accuracy: 0.9805 - val_loss: 0.6057 - val_categorical_accuracy: 0.8552 - lr: 0.0020
# Epoch 5/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1950 - categorical_accuracy: 0.9819
# Epoch 5: val_categorical_accuracy improved from 0.90379 to 0.95137, saving model to logs/fit/20230504-115255/models/model.05-0.95.hdf5
# 225/225 [==============================] - 157s 699ms/step - loss: 0.1950 - categorical_accuracy: 0.9819 - val_loss: 0.3140 - val_categorical_accuracy: 0.9514 - lr: 0.0020
# Epoch 6/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1761 - categorical_accuracy: 0.9851
# Epoch 6: val_categorical_accuracy did not improve from 0.95137
# 225/225 [==============================] - 160s 713ms/step - loss: 0.1761 - categorical_accuracy: 0.9851 - val_loss: 0.2953 - val_categorical_accuracy: 0.9375 - lr: 0.0020
# Epoch 7/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1649 - categorical_accuracy: 0.9867
# Epoch 7: val_categorical_accuracy did not improve from 0.95137
# 225/225 [==============================] - 159s 707ms/step - loss: 0.1649 - categorical_accuracy: 0.9867 - val_loss: 0.3493 - val_categorical_accuracy: 0.9194 - lr: 0.0020
# Epoch 8/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1664 - categorical_accuracy: 0.9861
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 8: val_categorical_accuracy did not improve from 0.95137
# 225/225 [==============================] - 160s 709ms/step - loss: 0.1664 - categorical_accuracy: 0.9861 - val_loss: 0.3205 - val_categorical_accuracy: 0.9344 - lr: 0.0020
# Epoch 9/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1032 - categorical_accuracy: 0.9940
# Epoch 9: val_categorical_accuracy improved from 0.95137 to 0.97221, saving model to logs/fit/20230504-115255/models/model.09-0.97.hdf5
# 225/225 [==============================] - 159s 707ms/step - loss: 0.1032 - categorical_accuracy: 0.9940 - val_loss: 0.1553 - val_categorical_accuracy: 0.9722 - lr: 0.0010
# Epoch 10/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0953 - categorical_accuracy: 0.9933
# Epoch 10: val_categorical_accuracy did not improve from 0.97221
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0953 - categorical_accuracy: 0.9933 - val_loss: 0.1676 - val_categorical_accuracy: 0.9687 - lr: 0.0010
# Epoch 11/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0941 - categorical_accuracy: 0.9935
# Epoch 11: val_categorical_accuracy improved from 0.97221 to 0.98576, saving model to logs/fit/20230504-115255/models/model.11-0.99.hdf5
# 225/225 [==============================] - 161s 715ms/step - loss: 0.0941 - categorical_accuracy: 0.9935 - val_loss: 0.1122 - val_categorical_accuracy: 0.9858 - lr: 0.0010
# Epoch 12/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0944 - categorical_accuracy: 0.9931
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_categorical_accuracy improved from 0.98576 to 0.99097, saving model to logs/fit/20230504-115255/models/model.12-0.99.hdf5
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0944 - categorical_accuracy: 0.9931 - val_loss: 0.0979 - val_categorical_accuracy: 0.9910 - lr: 0.0010
# Epoch 13/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0667 - categorical_accuracy: 0.9974
# Epoch 13: val_categorical_accuracy improved from 0.99097 to 0.99271, saving model to logs/fit/20230504-115255/models/model.13-0.99.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0667 - categorical_accuracy: 0.9974 - val_loss: 0.0787 - val_categorical_accuracy: 0.9927 - lr: 5.0000e-04
# Epoch 14/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0616 - categorical_accuracy: 0.9962
# Epoch 14: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0616 - categorical_accuracy: 0.9962 - val_loss: 0.0709 - val_categorical_accuracy: 0.9924 - lr: 5.0000e-04
# Epoch 15/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0606 - categorical_accuracy: 0.9965
# Epoch 15: val_categorical_accuracy improved from 0.99271 to 0.99618, saving model to logs/fit/20230504-115255/models/model.15-1.00.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0606 - categorical_accuracy: 0.9965 - val_loss: 0.0612 - val_categorical_accuracy: 0.9962 - lr: 5.0000e-04
# Epoch 16/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0617 - categorical_accuracy: 0.9957
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_categorical_accuracy did not improve from 0.99618
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0617 - categorical_accuracy: 0.9957 - val_loss: 0.0759 - val_categorical_accuracy: 0.9927 - lr: 5.0000e-04
# Epoch 17/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0482 - categorical_accuracy: 0.9986
# Epoch 17: val_categorical_accuracy did not improve from 0.99618
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0482 - categorical_accuracy: 0.9986 - val_loss: 0.0596 - val_categorical_accuracy: 0.9934 - lr: 2.5000e-04
# Epoch 18/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0454 - categorical_accuracy: 0.9980
# Epoch 18: val_categorical_accuracy did not improve from 0.99618
# 225/225 [==============================] - 159s 709ms/step - loss: 0.0454 - categorical_accuracy: 0.9980 - val_loss: 0.0628 - val_categorical_accuracy: 0.9920 - lr: 2.5000e-04
# Epoch 19/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0440 - categorical_accuracy: 0.9979
# Epoch 19: val_categorical_accuracy improved from 0.99618 to 0.99687, saving model to logs/fit/20230504-115255/models/model.19-1.00.hdf5
# 225/225 [==============================] - 158s 704ms/step - loss: 0.0440 - categorical_accuracy: 0.9979 - val_loss: 0.0449 - val_categorical_accuracy: 0.9969 - lr: 2.5000e-04
# Epoch 20/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0450 - categorical_accuracy: 0.9976
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 20: val_categorical_accuracy did not improve from 0.99687
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0450 - categorical_accuracy: 0.9976 - val_loss: 0.0460 - val_categorical_accuracy: 0.9969 - lr: 2.5000e-04
# Epoch 21/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0389 - categorical_accuracy: 0.9989
# Epoch 21: val_categorical_accuracy did not improve from 0.99687
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0389 - categorical_accuracy: 0.9989 - val_loss: 0.0458 - val_categorical_accuracy: 0.9958 - lr: 1.2500e-04
# Epoch 22/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0365 - categorical_accuracy: 0.9989
# Epoch 22: val_categorical_accuracy did not improve from 0.99687
# 225/225 [==============================] - 160s 709ms/step - loss: 0.0365 - categorical_accuracy: 0.9989 - val_loss: 0.0434 - val_categorical_accuracy: 0.9965 - lr: 1.2500e-04
# Epoch 23/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0361 - categorical_accuracy: 0.9986
# Epoch 23: val_categorical_accuracy improved from 0.99687 to 0.99722, saving model to logs/fit/20230504-115255/models/model.23-1.00.hdf5
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0361 - categorical_accuracy: 0.9986 - val_loss: 0.0417 - val_categorical_accuracy: 0.9972 - lr: 1.2500e-04
# Epoch 24/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0354 - categorical_accuracy: 0.9989
# Epoch 24: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0354 - categorical_accuracy: 0.9989 - val_loss: 0.0397 - val_categorical_accuracy: 0.9965 - lr: 1.2500e-04
# Epoch 25/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0355 - categorical_accuracy: 0.9985
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 25: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0355 - categorical_accuracy: 0.9985 - val_loss: 0.0434 - val_categorical_accuracy: 0.9958 - lr: 1.2500e-04
# Epoch 26/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0320 - categorical_accuracy: 0.9995
# Epoch 26: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0320 - categorical_accuracy: 0.9995 - val_loss: 0.0403 - val_categorical_accuracy: 0.9958 - lr: 6.2500e-05
# Epoch 27/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0315 - categorical_accuracy: 0.9993
# Epoch 27: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 161s 714ms/step - loss: 0.0315 - categorical_accuracy: 0.9993 - val_loss: 0.0376 - val_categorical_accuracy: 0.9969 - lr: 6.2500e-05
# Epoch 28/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0314 - categorical_accuracy: 0.9990
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 28: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0314 - categorical_accuracy: 0.9990 - val_loss: 0.0378 - val_categorical_accuracy: 0.9969 - lr: 6.2500e-05
# Epoch 29/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0303 - categorical_accuracy: 0.9993
# Epoch 29: val_categorical_accuracy did not improve from 0.99722
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0303 - categorical_accuracy: 0.9993 - val_loss: 0.0350 - val_categorical_accuracy: 0.9972 - lr: 3.1250e-05
# Epoch 30/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0300 - categorical_accuracy: 0.9991
# Epoch 30: val_categorical_accuracy improved from 0.99722 to 0.99792, saving model to logs/fit/20230504-115255/models/model.30-1.00.hdf5
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0300 - categorical_accuracy: 0.9991 - val_loss: 0.0322 - val_categorical_accuracy: 0.9979 - lr: 3.1250e-05
# Epoch 31/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0292 - categorical_accuracy: 0.9994
# Epoch 31: val_categorical_accuracy did not improve from 0.99792
# 225/225 [==============================] - 160s 712ms/step - loss: 0.0292 - categorical_accuracy: 0.9994 - val_loss: 0.0352 - val_categorical_accuracy: 0.9972 - lr: 3.1250e-05
# Epoch 32/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0292 - categorical_accuracy: 0.9994
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 32: val_categorical_accuracy did not improve from 0.99792
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0292 - categorical_accuracy: 0.9994 - val_loss: 0.0374 - val_categorical_accuracy: 0.9976 - lr: 3.1250e-05
# Epoch 33/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0284 - categorical_accuracy: 0.9995
# Epoch 33: val_categorical_accuracy improved from 0.99792 to 0.99826, saving model to logs/fit/20230504-115255/models/model.33-1.00.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0284 - categorical_accuracy: 0.9995 - val_loss: 0.0318 - val_categorical_accuracy: 0.9983 - lr: 1.5625e-05
# Epoch 34/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0283 - categorical_accuracy: 0.9996
# Epoch 34: val_categorical_accuracy improved from 0.99826 to 0.99861, saving model to logs/fit/20230504-115255/models/model.34-1.00.hdf5
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0283 - categorical_accuracy: 0.9996 - val_loss: 0.0311 - val_categorical_accuracy: 0.9986 - lr: 1.5625e-05
# Epoch 35/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0282 - categorical_accuracy: 0.9995
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 35: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 158s 704ms/step - loss: 0.0282 - categorical_accuracy: 0.9995 - val_loss: 0.0319 - val_categorical_accuracy: 0.9972 - lr: 1.5625e-05
# Epoch 36/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0279 - categorical_accuracy: 0.9995
# Epoch 36: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0279 - categorical_accuracy: 0.9995 - val_loss: 0.0306 - val_categorical_accuracy: 0.9979 - lr: 7.8125e-06
# Epoch 37/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0279 - categorical_accuracy: 0.9995
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 37: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0279 - categorical_accuracy: 0.9995 - val_loss: 0.0313 - val_categorical_accuracy: 0.9976 - lr: 7.8125e-06
# Epoch 38/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0278 - categorical_accuracy: 0.9995
# Epoch 38: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0278 - categorical_accuracy: 0.9995 - val_loss: 0.0320 - val_categorical_accuracy: 0.9976 - lr: 3.9063e-06
# Epoch 39/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9997
# Epoch 39: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 158s 702ms/step - loss: 0.0274 - categorical_accuracy: 0.9997 - val_loss: 0.0312 - val_categorical_accuracy: 0.9979 - lr: 3.9063e-06
# Epoch 40/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0275 - categorical_accuracy: 0.9995
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 40: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0275 - categorical_accuracy: 0.9995 - val_loss: 0.0313 - val_categorical_accuracy: 0.9976 - lr: 3.9063e-06
# Epoch 41/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0275 - categorical_accuracy: 0.9995
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 41: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0275 - categorical_accuracy: 0.9995 - val_loss: 0.0320 - val_categorical_accuracy: 0.9972 - lr: 1.9531e-06
# Epoch 42/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0275 - categorical_accuracy: 0.9995
# Epoch 42: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0275 - categorical_accuracy: 0.9995 - val_loss: 0.0315 - val_categorical_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 43/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9995
# Epoch 43: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0274 - categorical_accuracy: 0.9995 - val_loss: 0.0314 - val_categorical_accuracy: 0.9969 - lr: 1.0000e-06
# Epoch 44/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0271 - categorical_accuracy: 0.9997
# Epoch 44: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0271 - categorical_accuracy: 0.9997 - val_loss: 0.0315 - val_categorical_accuracy: 0.9969 - lr: 1.0000e-06
# Epoch 45/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0276 - categorical_accuracy: 0.9994
# Epoch 45: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0276 - categorical_accuracy: 0.9994 - val_loss: 0.0314 - val_categorical_accuracy: 0.9979 - lr: 1.0000e-06
# Epoch 46/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0275 - categorical_accuracy: 0.9995
# Epoch 46: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0275 - categorical_accuracy: 0.9995 - val_loss: 0.0313 - val_categorical_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 47/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9996
# Epoch 47: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0274 - categorical_accuracy: 0.9996 - val_loss: 0.0312 - val_categorical_accuracy: 0.9979 - lr: 1.0000e-06
# Epoch 48/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0273 - categorical_accuracy: 0.9997
# Epoch 48: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0273 - categorical_accuracy: 0.9997 - val_loss: 0.0314 - val_categorical_accuracy: 0.9979 - lr: 1.0000e-06
# Epoch 49/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0273 - categorical_accuracy: 0.9996
# Epoch 49: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0273 - categorical_accuracy: 0.9996 - val_loss: 0.0311 - val_categorical_accuracy: 0.9979 - lr: 1.0000e-06
# Epoch 50/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0274 - categorical_accuracy: 0.9995
# Epoch 50: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0274 - categorical_accuracy: 0.9995 - val_loss: 0.0310 - val_categorical_accuracy: 0.9979 - lr: 1.0000e-06
# Epoch 51/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0272 - categorical_accuracy: 0.9996Restoring model weights from the end of the best epoch: 44.
#
# Epoch 51: val_categorical_accuracy did not improve from 0.99861
# 225/225 [==============================] - 167s 744ms/step - loss: 0.0272 - categorical_accuracy: 0.9996 - val_loss: 0.0305 - val_categorical_accuracy: 0.9986 - lr: 1.0000e-06
# Epoch 51: early stopping
# 0.9986106157302856
# 360/360 [==============================] - 15s 41ms/step
# 57566
# 11513
# 2879
# 57566
# 11513
# 2879
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_12 (Bat  (None, 75, 16)           64
#  chNormalization)
#
#  conv1d_6 (Conv1D)           (None, 73, 64)            3136
#
#  batch_normalization_13 (Bat  (None, 73, 64)           256
#  chNormalization)
#
#  gru_6 (GRU)                 (None, 73, 75)            31725
#
#  batch_normalization_14 (Bat  (None, 73, 75)           300
#  chNormalization)
#
#  conv1d_7 (Conv1D)           (None, 71, 64)            14464
#
#  batch_normalization_15 (Bat  (None, 71, 64)           256
#  chNormalization)
#
#  gru_7 (GRU)                 (None, 71, 75)            31725
#
#  conv1d_8 (Conv1D)           (None, 69, 64)            14464
#
#  batch_normalization_16 (Bat  (None, 69, 64)           256
#  chNormalization)
#
#  gru_8 (GRU)                 (None, 75)                31725
#
#  batch_normalization_17 (Bat  (None, 75)               300
#  chNormalization)
#
#  dense_2 (Dense)             (None, 36)                2736
#
# =================================================================
# Total params: 131,407
# Trainable params: 130,691
# Non-trainable params: 716
# _________________________________________________________________
# None
# Epoch 1/60
# 225/225 [==============================] - ETA: 0s - loss: 4.0790 - categorical_accuracy: 0.4066
# Epoch 1: val_categorical_accuracy improved from -inf to 0.03369, saving model to logs/fit/20230504-140839/models/model.01-0.03.hdf5
# 225/225 [==============================] - 164s 710ms/step - loss: 4.0790 - categorical_accuracy: 0.4066 - val_loss: 4.7455 - val_categorical_accuracy: 0.0337 - lr: 0.0020
# Epoch 2/60
# 225/225 [==============================] - ETA: 0s - loss: 0.5303 - categorical_accuracy: 0.9281
# Epoch 2: val_categorical_accuracy improved from 0.03369 to 0.49496, saving model to logs/fit/20230504-140839/models/model.02-0.49.hdf5
# 225/225 [==============================] - 160s 712ms/step - loss: 0.5303 - categorical_accuracy: 0.9281 - val_loss: 1.6716 - val_categorical_accuracy: 0.4950 - lr: 0.0020
# Epoch 3/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2753 - categorical_accuracy: 0.9697
# Epoch 3: val_categorical_accuracy improved from 0.49496 to 0.93053, saving model to logs/fit/20230504-140839/models/model.03-0.93.hdf5
# 225/225 [==============================] - 160s 711ms/step - loss: 0.2753 - categorical_accuracy: 0.9697 - val_loss: 0.3704 - val_categorical_accuracy: 0.9305 - lr: 0.0020
# Epoch 4/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2323 - categorical_accuracy: 0.9754
# Epoch 4: val_categorical_accuracy did not improve from 0.93053
# 225/225 [==============================] - 159s 706ms/step - loss: 0.2323 - categorical_accuracy: 0.9754 - val_loss: 0.6467 - val_categorical_accuracy: 0.8093 - lr: 0.0020
# Epoch 5/60
# 225/225 [==============================] - ETA: 0s - loss: 0.2021 - categorical_accuracy: 0.9795
# Epoch 5: val_categorical_accuracy improved from 0.93053 to 0.94616, saving model to logs/fit/20230504-140839/models/model.05-0.95.hdf5
# 225/225 [==============================] - 162s 719ms/step - loss: 0.2021 - categorical_accuracy: 0.9795 - val_loss: 0.3105 - val_categorical_accuracy: 0.9462 - lr: 0.0020
# Epoch 6/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1843 - categorical_accuracy: 0.9829
# Epoch 6: val_categorical_accuracy improved from 0.94616 to 0.96735, saving model to logs/fit/20230504-140839/models/model.06-0.97.hdf5
# 225/225 [==============================] - 168s 747ms/step - loss: 0.1843 - categorical_accuracy: 0.9829 - val_loss: 0.2228 - val_categorical_accuracy: 0.9673 - lr: 0.0020
# Epoch 7/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1735 - categorical_accuracy: 0.9832
# Epoch 7: val_categorical_accuracy did not improve from 0.96735
# 225/225 [==============================] - 167s 743ms/step - loss: 0.1735 - categorical_accuracy: 0.9832 - val_loss: 0.2294 - val_categorical_accuracy: 0.9625 - lr: 0.0020
# Epoch 8/60
# 225/225 [==============================] - ETA: 0s - loss: 0.1644 - categorical_accuracy: 0.9845
# Epoch 8: val_categorical_accuracy did not improve from 0.96735
# 225/225 [==============================] - 165s 734ms/step - loss: 0.1644 - categorical_accuracy: 0.9845 - val_loss: 0.5725 - val_categorical_accuracy: 0.8597 - lr: 0.0020
# Epoch 9/60
# ...
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 19: val_categorical_accuracy improved from 0.94929 to 0.95450, saving model to logs/fit/20230504-181452/models/model.19-0.95.hdf5
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0739 - categorical_accuracy: 0.9931 - val_loss: 0.2027 - val_categorical_accuracy: 0.9545 - lr: 0.0010
# Epoch 20/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0536 - categorical_accuracy: 0.9968
# Epoch 20: val_categorical_accuracy did not improve from 0.95450
# 225/225 [==============================] - 160s 709ms/step - loss: 0.0536 - categorical_accuracy: 0.9968 - val_loss: 0.2651 - val_categorical_accuracy: 0.9462 - lr: 5.0000e-04
# Epoch 21/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0431 - categorical_accuracy: 0.9970
# Epoch 21: val_categorical_accuracy did not improve from 0.95450
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0431 - categorical_accuracy: 0.9970 - val_loss: 0.2375 - val_categorical_accuracy: 0.9350 - lr: 5.0000e-04
# Epoch 22/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0425 - categorical_accuracy: 0.9969
# Epoch 22: val_categorical_accuracy improved from 0.95450 to 0.96110, saving model to logs/fit/20230504-181452/models/model.22-0.96.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0425 - categorical_accuracy: 0.9969 - val_loss: 0.1366 - val_categorical_accuracy: 0.9611 - lr: 5.0000e-04
# Epoch 23/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0434 - categorical_accuracy: 0.9965
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 23: val_categorical_accuracy did not improve from 0.96110
# 225/225 [==============================] - 159s 709ms/step - loss: 0.0434 - categorical_accuracy: 0.9965 - val_loss: 0.1502 - val_categorical_accuracy: 0.9601 - lr: 5.0000e-04
# Epoch 24/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0322 - categorical_accuracy: 0.9984
# Epoch 24: val_categorical_accuracy did not improve from 0.96110
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0322 - categorical_accuracy: 0.9984 - val_loss: 0.1743 - val_categorical_accuracy: 0.9569 - lr: 2.5000e-04
# Epoch 25/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0272 - categorical_accuracy: 0.9986
# Epoch 25: val_categorical_accuracy improved from 0.96110 to 0.97256, saving model to logs/fit/20230504-181452/models/model.25-0.97.hdf5
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0272 - categorical_accuracy: 0.9986 - val_loss: 0.0911 - val_categorical_accuracy: 0.9726 - lr: 2.5000e-04
# Epoch 26/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0267 - categorical_accuracy: 0.9985
# Epoch 26: val_categorical_accuracy did not improve from 0.97256
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0267 - categorical_accuracy: 0.9985 - val_loss: 0.1033 - val_categorical_accuracy: 0.9708 - lr: 2.5000e-04
# Epoch 27/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0268 - categorical_accuracy: 0.9982
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 27: val_categorical_accuracy did not improve from 0.97256
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0268 - categorical_accuracy: 0.9982 - val_loss: 0.1608 - val_categorical_accuracy: 0.9573 - lr: 2.5000e-04
# Epoch 28/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0226 - categorical_accuracy: 0.9991
# Epoch 28: val_categorical_accuracy improved from 0.97256 to 0.98020, saving model to logs/fit/20230504-181452/models/model.28-0.98.hdf5
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0226 - categorical_accuracy: 0.9991 - val_loss: 0.0759 - val_categorical_accuracy: 0.9802 - lr: 1.2500e-04
# Epoch 29/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0209 - categorical_accuracy: 0.9989
# Epoch 29: val_categorical_accuracy did not improve from 0.98020
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0209 - categorical_accuracy: 0.9989 - val_loss: 0.0900 - val_categorical_accuracy: 0.9726 - lr: 1.2500e-04
# Epoch 30/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0204 - categorical_accuracy: 0.9990
# Epoch 30: val_categorical_accuracy did not improve from 0.98020
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0204 - categorical_accuracy: 0.9990 - val_loss: 0.0981 - val_categorical_accuracy: 0.9698 - lr: 1.2500e-04
# Epoch 31/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0196 - categorical_accuracy: 0.9989
# Epoch 31: val_categorical_accuracy did not improve from 0.98020
# 225/225 [==============================] - 159s 706ms/step - loss: 0.0196 - categorical_accuracy: 0.9989 - val_loss: 0.0705 - val_categorical_accuracy: 0.9802 - lr: 1.2500e-04
# Epoch 32/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0193 - categorical_accuracy: 0.9990
# Epoch 32: val_categorical_accuracy improved from 0.98020 to 0.98402, saving model to logs/fit/20230504-181452/models/model.32-0.98.hdf5
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0193 - categorical_accuracy: 0.9990 - val_loss: 0.0599 - val_categorical_accuracy: 0.9840 - lr: 1.2500e-04
# Epoch 33/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0186 - categorical_accuracy: 0.9991
# Epoch 33: val_categorical_accuracy did not improve from 0.98402
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0186 - categorical_accuracy: 0.9991 - val_loss: 0.0921 - val_categorical_accuracy: 0.9715 - lr: 1.2500e-04
# Epoch 34/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0190 - categorical_accuracy: 0.9990
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 34: val_categorical_accuracy did not improve from 0.98402
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0190 - categorical_accuracy: 0.9990 - val_loss: 0.0770 - val_categorical_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 35/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0169 - categorical_accuracy: 0.9995
# Epoch 35: val_categorical_accuracy did not improve from 0.98402
# 225/225 [==============================] - 158s 703ms/step - loss: 0.0169 - categorical_accuracy: 0.9995 - val_loss: 0.0609 - val_categorical_accuracy: 0.9826 - lr: 6.2500e-05
# Epoch 36/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0161 - categorical_accuracy: 0.9993
# Epoch 36: val_categorical_accuracy improved from 0.98402 to 0.98645, saving model to logs/fit/20230504-181452/models/model.36-0.99.hdf5
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0161 - categorical_accuracy: 0.9993 - val_loss: 0.0488 - val_categorical_accuracy: 0.9865 - lr: 6.2500e-05
# Epoch 37/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0158 - categorical_accuracy: 0.9995
# Epoch 37: val_categorical_accuracy did not improve from 0.98645
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0158 - categorical_accuracy: 0.9995 - val_loss: 0.1205 - val_categorical_accuracy: 0.9635 - lr: 6.2500e-05
# Epoch 38/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0152 - categorical_accuracy: 0.9995
# Epoch 38: val_categorical_accuracy improved from 0.98645 to 0.99201, saving model to logs/fit/20230504-181452/models/model.38-0.99.hdf5
# 225/225 [==============================] - 160s 712ms/step - loss: 0.0152 - categorical_accuracy: 0.9995 - val_loss: 0.0442 - val_categorical_accuracy: 0.9920 - lr: 6.2500e-05
# Epoch 39/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0149 - categorical_accuracy: 0.9995
# Epoch 39: val_categorical_accuracy did not improve from 0.99201
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0149 - categorical_accuracy: 0.9995 - val_loss: 0.0590 - val_categorical_accuracy: 0.9840 - lr: 6.2500e-05
# Epoch 40/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0154 - categorical_accuracy: 0.9993
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 40: val_categorical_accuracy did not improve from 0.99201
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0154 - categorical_accuracy: 0.9993 - val_loss: 0.0730 - val_categorical_accuracy: 0.9805 - lr: 6.2500e-05
# Epoch 41/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0143 - categorical_accuracy: 0.9996
# Epoch 41: val_categorical_accuracy did not improve from 0.99201
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0143 - categorical_accuracy: 0.9996 - val_loss: 0.0386 - val_categorical_accuracy: 0.9906 - lr: 3.1250e-05
# Epoch 42/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0138 - categorical_accuracy: 0.9997
# Epoch 42: val_categorical_accuracy improved from 0.99201 to 0.99271, saving model to logs/fit/20230504-181452/models/model.42-0.99.hdf5
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0138 - categorical_accuracy: 0.9997 - val_loss: 0.0378 - val_categorical_accuracy: 0.9927 - lr: 3.1250e-05
# Epoch 43/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0134 - categorical_accuracy: 0.9997
# Epoch 43: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 163s 726ms/step - loss: 0.0134 - categorical_accuracy: 0.9997 - val_loss: 0.0404 - val_categorical_accuracy: 0.9896 - lr: 3.1250e-05
# Epoch 44/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0137 - categorical_accuracy: 0.9995
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 44: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0137 - categorical_accuracy: 0.9995 - val_loss: 0.0438 - val_categorical_accuracy: 0.9892 - lr: 3.1250e-05
# Epoch 45/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0132 - categorical_accuracy: 0.9996
# Epoch 45: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0132 - categorical_accuracy: 0.9996 - val_loss: 0.0437 - val_categorical_accuracy: 0.9892 - lr: 1.5625e-05
# Epoch 46/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0129 - categorical_accuracy: 0.9997
# Epoch 46: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0129 - categorical_accuracy: 0.9997 - val_loss: 0.0388 - val_categorical_accuracy: 0.9917 - lr: 1.5625e-05
# Epoch 47/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0126 - categorical_accuracy: 0.9997
# Epoch 47: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0126 - categorical_accuracy: 0.9997 - val_loss: 0.0420 - val_categorical_accuracy: 0.9903 - lr: 1.5625e-05
# Epoch 48/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0127 - categorical_accuracy: 0.9997
# Epoch 48: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 48: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0127 - categorical_accuracy: 0.9997 - val_loss: 0.0502 - val_categorical_accuracy: 0.9903 - lr: 1.5625e-05
# Epoch 49/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0125 - categorical_accuracy: 0.9998
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 49: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 707ms/step - loss: 0.0125 - categorical_accuracy: 0.9998 - val_loss: 0.0499 - val_categorical_accuracy: 0.9871 - lr: 7.8125e-06
# Epoch 50/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0123 - categorical_accuracy: 0.9998
# Epoch 50: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 711ms/step - loss: 0.0123 - categorical_accuracy: 0.9998 - val_loss: 0.0417 - val_categorical_accuracy: 0.9906 - lr: 3.9063e-06
# Epoch 51/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9998
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 51: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0122 - categorical_accuracy: 0.9998 - val_loss: 0.0431 - val_categorical_accuracy: 0.9906 - lr: 3.9063e-06
# Epoch 52/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0126 - categorical_accuracy: 0.9995
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 52: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0126 - categorical_accuracy: 0.9995 - val_loss: 0.0417 - val_categorical_accuracy: 0.9910 - lr: 1.9531e-06
# Epoch 53/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9998
# Epoch 53: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0122 - categorical_accuracy: 0.9998 - val_loss: 0.0407 - val_categorical_accuracy: 0.9913 - lr: 1.0000e-06
# Epoch 54/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9998
# Epoch 54: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 709ms/step - loss: 0.0122 - categorical_accuracy: 0.9998 - val_loss: 0.0414 - val_categorical_accuracy: 0.9913 - lr: 1.0000e-06
# Epoch 55/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9998
# Epoch 55: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0122 - categorical_accuracy: 0.9998 - val_loss: 0.0424 - val_categorical_accuracy: 0.9906 - lr: 1.0000e-06
# Epoch 56/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9996
# Epoch 56: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0122 - categorical_accuracy: 0.9996 - val_loss: 0.0419 - val_categorical_accuracy: 0.9910 - lr: 1.0000e-06
# Epoch 57/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0123 - categorical_accuracy: 0.9998
# Epoch 57: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0123 - categorical_accuracy: 0.9998 - val_loss: 0.0407 - val_categorical_accuracy: 0.9906 - lr: 1.0000e-06
# Epoch 58/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0121 - categorical_accuracy: 0.9998
# Epoch 58: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 160s 710ms/step - loss: 0.0121 - categorical_accuracy: 0.9998 - val_loss: 0.0413 - val_categorical_accuracy: 0.9906 - lr: 1.0000e-06
# Epoch 59/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0120 - categorical_accuracy: 0.9998
# Epoch 59: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 708ms/step - loss: 0.0120 - categorical_accuracy: 0.9998 - val_loss: 0.0416 - val_categorical_accuracy: 0.9906 - lr: 1.0000e-06
# Epoch 60/60
# 225/225 [==============================] - ETA: 0s - loss: 0.0122 - categorical_accuracy: 0.9997
# Epoch 60: val_categorical_accuracy did not improve from 0.99271
# 225/225 [==============================] - 159s 705ms/step - loss: 0.0122 - categorical_accuracy: 0.9997 - val_loss: 0.0413 - val_categorical_accuracy: 0.9906 - lr: 1.0000e-06
# 0.9927058219909668
# 360/360 [==============================] - 17s 47ms/step

# %%
# CONFUSION MATRIX


y_test_class = [oh_dict[i] for i in np.concatenate(y_int_test_class)]
y_pred_class=[oh_dict[i] for i in np.concatenate(y_int_pred_class)]
confusion_mat = confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys()))
plt.imshow(confusion_mat, cmap=plt.cm.Blues)
plt.title('Confusion matrix')
plt.colorbar()
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.xticks([cl for cl in range(num_classes)], sign_types_dict.keys())
plt.yticks([cl for cl in range(num_classes)], sign_types_dict.keys())
plt.show()

df_cm = pd.DataFrame(confusion_mat, index=list(sign_types_dict.keys()), columns=list(sign_types_dict.keys()))
cmap = 'PuRd'
#pp_matrix(df_cm, cmap=cmap)

# tf.math.confusion_matrix(Y_test,y_pred)
# #%%
# # ROC PLOT
# fpr = {}
# tpr = {}
# roc_auc = {}
#
# for i in range(3):
#     fpr[i], tpr[i], _ = roc_curve(Y_test[:, i], y_pred[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])
#
# plt.figure()
# for i in range(3):
#     plt.plot(fpr[i], tpr[i], label='ROC curve for class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.0])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC curves for all classes')
# plt.legend(loc="lower right")
# plt.show()

# %%
a=confusion_mat.ravel()

# %%
tn, fp, fn, tp = confusion_matrix((y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
# Out:
#   Cell In[12], line 1
#     tn, fp, fn, tp = confusion_matrix((y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
#                                                                          ^
# SyntaxError: invalid syntax

# %%
tn, fp, fn, tp = confusion_matrix((y_test_class, y_pred_class, labels=list(sign_types_dict.keys()))).ravel()
# Out:
#   Cell In[13], line 1
#     tn, fp, fn, tp = confusion_matrix((y_test_class, y_pred_class, labels=list(sign_types_dict.keys()))).ravel()
#                                                                          ^
# SyntaxError: invalid syntax

# %%
tn, fp, fn, tp = confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tn, fp, fn, tp = confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
#
# ValueError: too many values to unpack (expected 4)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test_class, y_pred_class, labels=list(sign_types_dict.keys())))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.93      1.00      0.97      1610
#            ą       0.97      0.99      0.98      1605
#            b       0.94      1.00      0.97      1610
#            c       0.98      0.97      0.97      1610
#            ć       0.98      1.00      0.99      1610
#           ch       0.99      0.90      0.94      1610
#           cz       0.95      1.00      0.97      1605
#            d       1.00      0.98      0.99      1610
#            e       0.98      1.00      0.99      1610
#            ę       1.00      1.00      1.00      1449
#            f       0.99      1.00      1.00      1610
#            g       1.00      0.99      1.00      1605
#            h       0.99      0.98      0.99      1605
#            i       0.98      1.00      0.99      1605
#            j       0.94      1.00      0.97      1610
#            k       0.89      0.94      0.91      1605
#            l       0.99      1.00      0.99      1605
#            ł       1.00      0.95      0.97      1610
#            m       0.99      1.00      0.99      1610
#            n       1.00      1.00      1.00      1610
#            ń       0.98      0.98      0.98      1610
#            o       0.91      0.94      0.93      1610
#            ó       0.97      0.99      0.98      1605
#            p       0.99      1.00      0.99      1610
#            r       1.00      1.00      1.00      1610
#           rz       1.00      0.99      1.00      1605
#            s       0.98      0.92      0.95      1610
#            ś       0.98      1.00      0.99      1449
#           sz       0.99      0.92      0.96      1605
#            t       0.98      0.97      0.98      1605
#            u       1.00      0.90      0.95      1610
#            w       1.00      0.99      1.00      1605
#            y       1.00      0.89      0.94      1605
#            z       0.98      0.99      0.98      1610
#            ź       1.00      0.97      0.99      1605
#            ż       0.93      0.99      0.96      1605
#
#     accuracy                           0.98     57563
#    macro avg       0.98      0.98      0.98     57563
# weighted avg       0.98      0.98      0.98     57563

# %%
from sklearn.metrics import multilabel_confusion_matrix

# %%
confusion_matmm = multilabel_confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys()))

# %%
plt.imshow(confusion_matmm, cmap=plt.cm.Blues)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.imshow(confusion_matmm, cmap=plt.cm.Blues)
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=447'>448</a> if len(args) > name_idx:
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=448'>449</a>     warn_deprecated(
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=449'>450</a>         since, message="Passing the %(name)s %(obj_type)s "
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=450'>451</a>         "positionally is deprecated since Matplotlib %(since)s; the "
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=451'>452</a>         "parameter will become keyword-only %(removal)s.",
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=452'>453</a>         name=name, obj_type=f"parameter of {func.__name__}()")
# --> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=453'>454</a> return func(*args, **kwargs)
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py:2631, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2624'>2625</a> @_copy_docstring_and_deprecators(Axes.imshow)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2625'>2626</a> def imshow(
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2626'>2627</a>         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2627'>2628</a>         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2628'>2629</a>         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2629'>2630</a>         resample=None, url=None, data=None, **kwargs):
# -> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2630'>2631</a>     __ret = gca().imshow(
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2631'>2632</a>         X, cmap=cmap, norm=norm, aspect=aspect,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2632'>2633</a>         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2633'>2634</a>         vmax=vmax, origin=origin, extent=extent,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2634'>2635</a>         interpolation_stage=interpolation_stage,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2635'>2636</a>         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2636'>2637</a>         url=url, **({"data": data} if data is not None else {}),
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2637'>2638</a>         **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2638'>2639</a>     sci(__ret)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2639'>2640</a>     return __ret
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=447'>448</a> if len(args) > name_idx:
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=448'>449</a>     warn_deprecated(
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=449'>450</a>         since, message="Passing the %(name)s %(obj_type)s "
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=450'>451</a>         "positionally is deprecated since Matplotlib %(since)s; the "
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=451'>452</a>         "parameter will become keyword-only %(removal)s.",
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=452'>453</a>         name=name, obj_type=f"parameter of {func.__name__}()")
# --> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/_api/deprecation.py?line=453'>454</a> return func(*args, **kwargs)
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1429'>1430</a> @functools.wraps(func)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1430'>1431</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1431'>1432</a>     if data is None:
# -> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1432'>1433</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1434'>1435</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1435'>1436</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/__init__.py?line=1436'>1437</a>                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5610, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5601'>5602</a> self.set_aspect(aspect)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5602'>5603</a> im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5603'>5604</a>                       interpolation=interpolation, origin=origin,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5604'>5605</a>                       extent=extent, filternorm=filternorm,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5605'>5606</a>                       filterrad=filterrad, resample=resample,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5606'>5607</a>                       interpolation_stage=interpolation_stage,
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5607'>5608</a>                       **kwargs)
# -> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5609'>5610</a> im.set_data(X)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5610'>5611</a> im.set_alpha(alpha)
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5611'>5612</a> if im.get_clip_path() is None:
#    <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=5612'>5613</a>     # image does not already have clipping set, clip to axes patch
#
# File ~/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py:710, in _ImageBase.set_data(self, A)
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=705'>706</a>     self._A = self._A[:, :, 0]
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=707'>708</a> if not (self._A.ndim == 2
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=708'>709</a>         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=709'>710</a>     raise TypeError("Invalid shape {} for image data"
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=710'>711</a>                     .format(self._A.shape))
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=712'>713</a> if self._A.ndim == 3:
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=713'>714</a>     # If the input data has values outside the valid range (after
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=714'>715</a>     # normalisation), we issue a warning and then clip X to the bounds
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=715'>716</a>     # - otherwise casting wraps extreme values, hiding outliers and
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=716'>717</a>     # making reliable interpretation impossible.
#     <a href='file:///home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/python3.9/site-packages/matplotlib/image.py?line=717'>718</a>     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (36, 2, 2) for image data

# %%
tn, fp, fn, tp = multilabel_confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tn, fp, fn, tp = multilabel_confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys())).ravel()
#
# ValueError: too many values to unpack (expected 4)

# %%
TP = confusion_matrix[0][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 TP = confusion_matrix[0][0]
#
# TypeError: 'function' object is not subscriptable

# %%
TP = confusion_mat[0][0]

# %%
TP
# Out:
# 1610

# %%
FP = cm[0][1]
FN = cm[1][0]
TN = cm[1][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 FP = cm[0][1]
#       2 FN = cm[1][0]
#       3 TN = cm[1][1]
#
# NameError: name 'cm' is not defined

# %%
FP = confusion_mat[0][1]
FN = confusion_mat[1][0]
TN = confusion_mat[1][1]

# %%
Sensitivity = TP/(TP+FN)

# %%
Sensitivity
# Out:
# 1.0

# %%
Specifity = TN/(TN+FP)

# %%
Specifity
# Out:
# 1.0

# %%
TP
FP
# Out:
# 0

# %%
TP
# Out:
# 1610

# %%
FP
# Out:
# 0

# %%
FN
# Out:
# 0

# %%
cnf_matrix = confusion_mat

# %%
FP = cnf_matrix.sum(axis=0) - np.diag(cnf_matrix)

# %%
FN = cnf_matrix.sum(axis=1) - np.diag(cnf_matrix)

# %%
TP = np.diag(cnf_matrix)

# %%
TN = cnf_matrix.sum() - (FP + FN + TP)

# %%
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP) 
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)
# Overall accuracy for each class
ACC = (TP+TN)/(TP+FP+FN+TN)

# %%
TPR
# Out:
# array([1.        , 0.99439252, 1.        , 0.9689441 , 0.99751553,
#        0.89937888, 1.        , 0.98136646, 1.        , 1.        ,
#        0.99813665, 0.99376947, 0.98317757, 0.99937695, 0.99503106,
#        0.94143302, 0.99750779, 0.9515528 , 0.99751553, 0.99937888,
#        0.97639752, 0.94347826, 0.99314642, 1.        , 0.99937888,
#        0.99376947, 0.9173913 , 0.99861974, 0.92024922, 0.97196262,
#        0.90186335, 0.99439252, 0.894081  , 0.98757764, 0.97320872,
#        0.98878505])

# %%
Sensitivity = TP/(TP+FN)

# %%
Specifity = TN/(TN+FP)

# %%
Sensitivity
# Out:
# array([1.        , 0.99439252, 1.        , 0.9689441 , 0.99751553,
#        0.89937888, 1.        , 0.98136646, 1.        , 1.        ,
#        0.99813665, 0.99376947, 0.98317757, 0.99937695, 0.99503106,
#        0.94143302, 0.99750779, 0.9515528 , 0.99751553, 0.99937888,
#        0.97639752, 0.94347826, 0.99314642, 1.        , 0.99937888,
#        0.99376947, 0.9173913 , 0.99861974, 0.92024922, 0.97196262,
#        0.90186335, 0.99439252, 0.894081  , 0.98757764, 0.97320872,
#        0.98878505])

# %%
np.average(Sensitivity)
# Out:
# 0.9764660807360249

# %%
np.average(Specifity)
# Out:
# 0.9993239040770151

# %%
Precision = TP/(TP+FP)

# %%
np.average(Precision)
# Out:
# 0.9772112616293082
