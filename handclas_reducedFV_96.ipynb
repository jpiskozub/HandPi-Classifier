# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime



#import psycopg as psql

import configparser

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay


from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras import layers, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
import tensorflow as tf


from keras.regularizers import l2


from tensorflow.keras.utils import timeseries_dataset_from_array, normalize



config = configparser.ConfigParser()
config.read('config.ini')



devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(devices[0], True)
# Out:
# 2023-04-11 16:34:23.563958: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 16:34:23.655153: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-11 16:34:24.012322: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/
# 2023-04-11 16:34:24.012401: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/kuba/anaconda3/envs/Handpi_classifier_ubu/lib/
# 2023-04-11 16:34:24.012405: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-04-11 16:34:24.625244: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:24.630465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:24.630516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
ADC_channels = ['P1_1', 'P1_2', 'P2_1', 'P2_2', 'P3_1', 'P3_2', 'P4_1', 'P4_2', 'P5_1', 'P5_2']
IMU_channels = ['Euler_x', 'Euler_y', 'Euler_z', 'Acc_x', 'Acc_y', 'Acc_z']

sign_types = ['static', 'dynamic']
sign_types_dict = {'a': sign_types[0],
                   'ą': sign_types[1],
                   'b': sign_types[0],
                   'c': sign_types[0],
                   'ć': sign_types[1],
                   'ch': sign_types[1],
                   'cz': sign_types[1],
                   'd': sign_types[1],
                   'e': sign_types[0],
                   'ę': sign_types[1],
                   'f': sign_types[1],
                   'g': sign_types[1],
                   'h': sign_types[1],
                   'i': sign_types[0],
                   'j': sign_types[1],
                   'k': sign_types[1],
                   'l': sign_types[0],
                   'ł': sign_types[1],
                   'm': sign_types[0],
                   'n': sign_types[0],
                   'ń': sign_types[1],
                   'o': sign_types[0],
                   'ó': sign_types[1],
                   'p': sign_types[0],
                   'r': sign_types[0],
                   'rz': sign_types[1],
                   's': sign_types[0],
                   'ś': sign_types[1],
                   'sz': sign_types[1],
                   't': sign_types[0],
                   'u': sign_types[0],
                   'w': sign_types[0],
                   'y': sign_types[0],
                   'z': sign_types[1],
                   'ź': sign_types[1],
                   'ż': sign_types[1]}


SAMPLE_SIZE = 75

# %%
# LOADING
#df = pd.read_csv("G:\Git_repos\HandPi-ETL\gesty.csv")
# df = pd.read_csv('G:/Git_repos/HandPi-ETL/gesty_pp_aug.csv')
# df = pd.concat([df, pd.read_csv('G:/Git_repos/HandPi-ETL/gesty_pp.csv')], ignore_index=True )
df = pd.read_csv("/mnt/g/Git_repos/HandPi-ETL/gesty_pp.csv")
df = df[df['exam_id'] != ('tt',15)]

# %%
# ADDING AUGMENTED DATA
adf = pd.read_csv("/mnt/g/Git_repos/HandPi-ETL/gesty_pp_aug.csv")
adf.columns = df.columns[0:19]
df = pd.concat([df, adf ], ignore_index=True)

# %%
# FEATURE SELECTION
df = df.drop(['P1_1', 'P2_1', 'P3_1', 'P4_1', 'P4_2', 'P5_1', 'P5_2'], axis=1)

# %%
# DATA CURING
df.fillna(method='backfill', inplace=True)
print(f'NaN containment:{df.isnull().any()}')
num_rows = df.shape[0] // SAMPLE_SIZE
num_ts = num_rows*SAMPLE_SIZE
# Out:
# NaN containment:exam_id       False
# P1_2          False
# P2_2          False
# P3_2          False
# Euler_x       False
# Euler_y       False
# Euler_z       False
# Acc_x         False
# Acc_y         False
# Acc_z         False
# sign          False
# timestamp     False
# gesture_id     True
# dtype: bool

# %%
# DATA AND LABELS
x = df.iloc[:num_ts,1:10].values
y = df['sign'].values

num_classes = len(np.unique(y))

# %%
# CONVERTING & ENCODING LABELS
Y_resh = np.reshape(y,(num_ts//SAMPLE_SIZE,SAMPLE_SIZE,1))
Y = Y_resh[:,1,:]

#Y_enc = [int.from_bytes(char.encode('utf-8'), byteorder="big") for char in Y ]

Y_enc = pd.get_dummies(Y.flatten())



X_resh = np.reshape(x,(num_ts//SAMPLE_SIZE, SAMPLE_SIZE, x.shape[1]))

# %%
# SPLITTING

skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(X_resh, Y_enc)

test_acc_list =[]
train_acc_list = []
y_int_pred_class = []
y_int_test_class = []


for i, (train_index, test_index) in enumerate(skf.split(X_resh, Y)):

    X_test1 = X_resh[test_index]
    X_train = X_resh[train_index]
    Y_train = Y_enc.iloc[train_index]
    Y_test1 =Y_enc.iloc[test_index]

    X_test, X_val, Y_test, Y_val = train_test_split(X_test1, Y_test1, test_size=0.2, random_state=0, stratify=Y_test1)

    print(X_train.shape[0])
    print(X_test.shape[0])
    print(X_val.shape[0])
    print(Y_train.shape[0])
    print(Y_test.shape[0])
    print(Y_val.shape[0])

    train_dataset = (X_train, Y_train)
    test_dataset = (X_test, Y_test)
    val_dataset = (X_val, Y_val)



#train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
#test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

## MODEL CONSTANTS
    LAYERS = np.dot(1,[75, 75, 75])                # number of units in hidden and output layers
    M_TRAIN = X_train.shape[0]                     # number of training examples (2D)
    M_TEST = X_test.shape[0]                       # number of test examples (2D),full=X_test.shape[0]
    N = X_train.shape[2]                           # number of features
    BATCH = 256                                    # batch size
    EPOCH = 100                                    # number of epochs
    LR = 2e-3                          # learning rate of the gradient descent
    LAMBD = 3e-2                         # lambda in L2 regularizaion
    DP = 0.5                           # dropout rate
    RDP = 0                           # recurrent dropout rate

    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

    checkpoint = ModelCheckpoint(filepath=log_dir+'/models/'+'model.{epoch:02d}-{val_categorical_accuracy:.2f}.hdf5',
                                 monitor='val_categorical_accuracy',
                                 verbose=1,
                                 save_best_only=True,
                                 save_weights_only=False,
                                 mode='max')

    lr_decay = ReduceLROnPlateau(monitor='loss',
                                 patience=1, verbose=1,
                                 factor=0.5, min_lr=1e-6)

    early_stop = EarlyStopping(monitor='categorical_accuracy', min_delta=0,
                               patience=7, verbose=1, mode='auto',
                               baseline=0, restore_best_weights=True)

    initial_learning_rate = LR
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=100000,
        decay_rate=0.96,
        staircase=True)


    # MODEL DEFINITION
    model = Sequential()
    model.add(layers.Input(shape=(X_train.shape[1], X_train.shape[2])))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[0],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=True, return_state=False,
                          stateful=False, unroll=False))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[1],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=True, return_state=False,
                          stateful=False, unroll=False))
    model.add(layers.Conv1D(filters=64, kernel_size=3, activation='sigmoid', input_shape=(75, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.GRU(units=LAYERS[2],
                          activation='selu', recurrent_activation='hard_sigmoid',
                          kernel_regularizer=l2(LAMBD), recurrent_regularizer=l2(LAMBD),
                          dropout=DP, recurrent_dropout=RDP,
                          return_sequences=False, return_state=False,
                          stateful=False, unroll=False))
    
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(36, activation='softmax'))

    opt = optimizers.Adam(learning_rate=LR,  clipnorm=1.)



    # MODEL COMPILATION
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['categorical_accuracy'])

    print(model.summary())


    # TRAINING
    history = model.fit(X_train, Y_train, epochs=EPOCH, batch_size=BATCH,
                        shuffle=True,validation_data=val_dataset,
                        callbacks=[
                                    early_stop
                                    ,lr_decay
                                    ,checkpoint
                                    ,tensorboard_callback]
                        )






    # EVALUATION
    # train_loss, train_acc = model.evaluate(X_train, Y_train,
    #                                        batch_size=M_TRAIN, verbose=0)
    test_loss, test_acc = model.evaluate(X_test, Y_test,
                                         batch_size=M_TEST, verbose=0)

    test_acc_list.append(test_acc)
    #train_acc_list.append(train_acc)

    # ACCURACY AND LOSS PLOTS

    print(max(history.history['val_categorical_accuracy']))

    plt.plot(history.history['val_loss'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('Model loss and accuracy')
    plt.ylabel('Loss/Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Loss', 'Accuracy'], loc='upper left')
    plt.show()


    y_pred = model.predict(X_test)
    
    
    y_int_pred_class.append(np.argmax(y_pred, axis=1))
    y_int_test_class.append(np.argmax(Y_test.values, axis=1))

    # CONFUSION MATRIX
oh_dict=dict(zip([i for i in range(num_classes)],list(sign_types_dict.keys())))
# Out:
# 57566
# 11513
# 2879
# 57566
# 11513
# 2879
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-04-11 16:34:44.081179: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 16:34:44.083405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.083456: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.083471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.982524: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.982691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.982699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-04-11 16:34:44.982753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-04-11 16:34:44.982925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5909 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 75, 9)            36
#  ormalization)
#
#  conv1d (Conv1D)             (None, 73, 64)            1792
#
#  batch_normalization_1 (Batc  (None, 73, 64)           256
#  hNormalization)
#
#  gru (GRU)                   (None, 73, 75)            31725
#
#  batch_normalization_2 (Batc  (None, 73, 75)           300
#  hNormalization)
#
#  conv1d_1 (Conv1D)           (None, 71, 64)            14464
#
#  batch_normalization_3 (Batc  (None, 71, 64)           256
#  hNormalization)
#
#  gru_1 (GRU)                 (None, 71, 75)            31725
#
#  conv1d_2 (Conv1D)           (None, 69, 64)            14464
#
#  batch_normalization_4 (Batc  (None, 69, 64)           256
#  hNormalization)
#
#  gru_2 (GRU)                 (None, 75)                31725
#
#  batch_normalization_5 (Batc  (None, 75)               300
#  hNormalization)
#
#  dense (Dense)               (None, 36)                2736
#
# =================================================================
# Total params: 130,035
# Trainable params: 129,333
# Non-trainable params: 702
# _________________________________________________________________
# None
# Epoch 1/100
# 2023-04-11 16:34:49.367736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-04-11 16:34:49.993723: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-04-11 16:34:51.467244: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7efcec00eee0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-11 16:34:51.467276: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 2070 SUPER, Compute Capability 7.5
# 2023-04-11 16:34:51.501521: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-11 16:34:51.818761: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 2023-04-11 16:34:51.842312: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-04-11 16:34:52.478053: W tensorflow/tsl/framework/bfc_allocator.cc:360] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 225/225 [==============================] - ETA: 0s - loss: 4.2684 - categorical_accuracy: 0.3446
# Epoch 1: val_categorical_accuracy improved from -inf to 0.07155, saving model to logs/fit/20230411-163444/models/model.01-0.07.hdf5
# 225/225 [==============================] - 192s 802ms/step - loss: 4.2684 - categorical_accuracy: 0.3446 - val_loss: 4.3818 - val_categorical_accuracy: 0.0716 - lr: 0.0020
# Epoch 2/100
# 225/225 [==============================] - ETA: 0s - loss: 0.6986 - categorical_accuracy: 0.8850
# Epoch 2: val_categorical_accuracy improved from 0.07155 to 0.41264, saving model to logs/fit/20230411-163444/models/model.02-0.41.hdf5
# 225/225 [==============================] - 181s 805ms/step - loss: 0.6986 - categorical_accuracy: 0.8850 - val_loss: 2.3328 - val_categorical_accuracy: 0.4126 - lr: 0.0020
# Epoch 3/100
# 225/225 [==============================] - ETA: 0s - loss: 0.
100
# 225/225 [==============================] - ETA: 0s - loss: 0.1706 - categorical_accuracy: 0.9799
# Epoch 14: val_categorical_accuracy did not improve from 0.85794
# 225/225 [==============================] - 172s 766ms/step - loss: 0.1706 - categorical_accuracy: 0.9799 - val_loss: 1.0941 - val_categorical_accuracy: 0.7954 - lr: 0.0020
# Epoch 15/100
# 225/225 [==============================] - ETA: 0s - loss: 0.1668 - categorical_accuracy: 0.9808
# Epoch 15: val_categorical_accuracy did not improve from 0.85794
# 225/225 [==============================] - 173s 768ms/step - loss: 0.1668 - categorical_accuracy: 0.9808 - val_loss: 1.3874 - val_categorical_accuracy: 0.7433 - lr: 0.0020
# Epoch 16/100
# 225/225 [==============================] - ETA: 0s - loss: 0.1552 - categorical_accuracy: 0.9822
# Epoch 16: val_categorical_accuracy did not improve from 0.85794
# 225/225 [==============================] - 174s 772ms/step - loss: 0.1552 - categorical_accuracy: 0.9822 - val_loss: 0.9719 - val_categorical_accuracy: 0.8388 - lr: 0.0020
# Epoch 17/100
# 225/225 [==============================] - ETA: 0s - loss: 0.1499 - categorical_accuracy: 0.9832
# Epoch 17: val_categorical_accuracy improved from 0.85794 to 0.86037, saving model to logs/fit/20230411-163444/models/model.17-0.86.hdf5
# 225/225 [==============================] - 174s 771ms/step - loss: 0.1499 - categorical_accuracy: 0.9832 - val_loss: 0.8354 - val_categorical_accuracy: 0.8604 - lr: 0.0020
# Epoch 18/100
# 225/225 [==============================] - ETA: 0s - loss: 0.1499 - categorical_accuracy: 0.9831
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 18: val_categorical_accuracy did not improve from 0.86037
# 225/225 [==============================] - 173s 767ms/step - loss: 0.1499 - categorical_accuracy: 0.9831 - val_loss: 0.7790 - val_categorical_accuracy: 0.8583 - lr: 0.0020
# Epoch 19/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0850 - categorical_accuracy: 0.9920
# Epoch 19: val_categorical_accuracy improved from 0.86037 to 0.87565, saving model to logs/fit/20230411-163444/models/model.19-0.88.hdf5
# 225/225 [==============================] - 173s 771ms/step - loss: 0.0850 - categorical_accuracy: 0.9920 - val_loss: 0.5701 - val_categorical_accuracy: 0.8757 - lr: 0.0010
# Epoch 20/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0715 - categorical_accuracy: 0.9922
# Epoch 20: val_categorical_accuracy did not improve from 0.87565
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0715 - categorical_accuracy: 0.9922 - val_loss: 0.9406 - val_categorical_accuracy: 0.8666 - lr: 0.0010
# Epoch 21/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0745 - categorical_accuracy: 0.9916
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_categorical_accuracy improved from 0.87565 to 0.88503, saving model to logs/fit/20230411-163444/models/model.21-0.89.hdf5
# 225/225 [==============================] - 173s 767ms/step - loss: 0.0745 - categorical_accuracy: 0.9916 - val_loss: 0.7252 - val_categorical_accuracy: 0.8850 - lr: 0.0010
# Epoch 22/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0502 - categorical_accuracy: 0.9964
# Epoch 22: val_categorical_accuracy did not improve from 0.88503
# 225/225 [==============================] - 172s 765ms/step - loss: 0.0502 - categorical_accuracy: 0.9964 - val_loss: 0.5400 - val_categorical_accuracy: 0.8812 - lr: 5.0000e-04
# Epoch 23/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0438 - categorical_accuracy: 0.9957
# Epoch 23: val_categorical_accuracy improved from 0.88503 to 0.90726, saving model to logs/fit/20230411-163444/models/model.23-0.91.hdf5
# 225/225 [==============================] - 172s 766ms/step - loss: 0.0438 - categorical_accuracy: 0.9957 - val_loss: 0.6188 - val_categorical_accuracy: 0.9073 - lr: 5.0000e-04
# Epoch 24/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0452 - categorical_accuracy: 0.9950
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 24: val_categorical_accuracy improved from 0.90726 to 0.92046, saving model to logs/fit/20230411-163444/models/model.24-0.92.hdf5
# 225/225 [==============================] - 172s 765ms/step - loss: 0.0452 - categorical_accuracy: 0.9950 - val_loss: 0.6424 - val_categorical_accuracy: 0.9205 - lr: 5.0000e-04
# Epoch 25/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0339 - categorical_accuracy: 0.9976
# Epoch 25: val_categorical_accuracy did not improve from 0.92046
# 225/225 [==============================] - 171s 761ms/step - loss: 0.0339 - categorical_accuracy: 0.9976 - val_loss: 0.5932 - val_categorical_accuracy: 0.9166 - lr: 2.5000e-04
# Epoch 26/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0302 - categorical_accuracy: 0.9977
# Epoch 26: val_categorical_accuracy did not improve from 0.92046
# 225/225 [==============================] - 172s 764ms/step - loss: 0.0302 - categorical_accuracy: 0.9977 - val_loss: 0.4710 - val_categorical_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 27/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0292 - categorical_accuracy: 0.9971
# Epoch 27: val_categorical_accuracy improved from 0.92046 to 0.92358, saving model to logs/fit/20230411-163444/models/model.27-0.92.hdf5
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0292 - categorical_accuracy: 0.9971 - val_loss: 0.6012 - val_categorical_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 28/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0285 - categorical_accuracy: 0.9973
# Epoch 28: val_categorical_accuracy improved from 0.92358 to 0.92706, saving model to logs/fit/20230411-163444/models/model.28-0.93.hdf5
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0285 - categorical_accuracy: 0.9973 - val_loss: 0.5334 - val_categorical_accuracy: 0.9271 - lr: 2.5000e-04
# Epoch 29/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0296 - categorical_accuracy: 0.9969
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 29: val_categorical_accuracy did not improve from 0.92706
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0296 - categorical_accuracy: 0.9969 - val_loss: 0.5361 - val_categorical_accuracy: 0.9239 - lr: 2.5000e-04
# Epoch 30/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0243 - categorical_accuracy: 0.9983
# Epoch 30: val_categorical_accuracy improved from 0.92706 to 0.93157, saving model to logs/fit/20230411-163444/models/model.30-0.93.hdf5
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0243 - categorical_accuracy: 0.9983 - val_loss: 0.4814 - val_categorical_accuracy: 0.9316 - lr: 1.2500e-04
# Epoch 31/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0218 - categorical_accuracy: 0.9985
# Epoch 31: val_categorical_accuracy did not improve from 0.93157
# 225/225 [==============================] - 173s 771ms/step - loss: 0.0218 - categorical_accuracy: 0.9985 - val_loss: 0.4780 - val_categorical_accuracy: 0.9305 - lr: 1.2500e-04
# Epoch 32/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.9982
# Epoch 32: val_categorical_accuracy improved from 0.93157 to 0.93366, saving model to logs/fit/20230411-163444/models/model.32-0.93.hdf5
# 225/225 [==============================] - 173s 769ms/step - loss: 0.0216 - categorical_accuracy: 0.9982 - val_loss: 0.4448 - val_categorical_accuracy: 0.9337 - lr: 1.2500e-04
# Epoch 33/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.9982
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 33: val_categorical_accuracy did not improve from 0.93366
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0216 - categorical_accuracy: 0.9982 - val_loss: 0.5013 - val_categorical_accuracy: 0.9323 - lr: 1.2500e-04
# Epoch 34/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0189 - categorical_accuracy: 0.9987
# Epoch 34: val_categorical_accuracy did not improve from 0.93366
# 225/225 [==============================] - 173s 770ms/step - loss: 0.
ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 48: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0146 - categorical_accuracy: 0.9992 - val_loss: 0.4903 - val_categorical_accuracy: 0.9361 - lr: 1.9531e-06
# Epoch 49/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0147 - categorical_accuracy: 0.9991
# Epoch 49: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0147 - categorical_accuracy: 0.9991 - val_loss: 0.4893 - val_categorical_accuracy: 0.9357 - lr: 1.0000e-06
# Epoch 50/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0144 - categorical_accuracy: 0.9992
# Epoch 50: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0144 - categorical_accuracy: 0.9992 - val_loss: 0.4896 - val_categorical_accuracy: 0.9364 - lr: 1.0000e-06
# Epoch 51/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0144 - categorical_accuracy: 0.9992
# Epoch 51: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0144 - categorical_accuracy: 0.9992 - val_loss: 0.4822 - val_categorical_accuracy: 0.9357 - lr: 1.0000e-06
# Epoch 52/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0141 - categorical_accuracy: 0.9991
# Epoch 52: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0141 - categorical_accuracy: 0.9991 - val_loss: 0.4837 - val_categorical_accuracy: 0.9361 - lr: 1.0000e-06
# Epoch 53/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0144 - categorical_accuracy: 0.9992
# Epoch 53: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 172s 765ms/step - loss: 0.0144 - categorical_accuracy: 0.9992 - val_loss: 0.4856 - val_categorical_accuracy: 0.9357 - lr: 1.0000e-06
# Epoch 54/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0142 - categorical_accuracy: 0.9993Restoring model weights from the end of the best epoch: 47.
#
# Epoch 54: val_categorical_accuracy did not improve from 0.93678
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0142 - categorical_accuracy: 0.9993 - val_loss: 0.4849 - val_categorical_accuracy: 0.9357 - lr: 1.0000e-06
# Epoch 54: early stopping
# 0.9367836117744446
# 360/360 [==============================] - 18s 50ms/step
# 57566
# 11513
# 2879
# 57566
# 11513
# 2879
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_6 (Batc  (None, 75, 9)            36
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 73, 64)            1792
#
#  batch_normalization_7 (Batc  (None, 73, 64)           256
#  hNormalization)
#
#  gru_3 (GRU)                 (None, 73, 75)            31725
#
#  batch_normalization_8 (Batc  (None, 73, 75)           300
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 71, 64)            14464
#
#  batch_normalization_9 (Batc  (None, 71, 64)           256
#  hNormalization)
#
#  gru_4 (GRU)                 (None, 71, 75)            31725
#
#  conv1d_5 (Conv1D)           (None, 69, 64)            14464
#
#  batch_normalization_10 (Bat  (None, 69, 64)           256
#  chNormalization)
#
#  gru_5 (GRU)                 (None, 75)                31725
#
#  batch_normalization_11 (Bat  (None, 75)               300
#  chNormalization)
#
#  dense_1 (Dense)             (None, 36)                2736
#
# =================================================================
# Total params: 130,035
# Trainable params: 129,333
# Non-trainable params: 702
# _________________________________________________________________
# None
# Epoch 1/100
# 225/225 [==============================] - ETA: 0s - loss: 4.1013 - categorical_accuracy: 0.4201
# Epoch 1: val_categorical_accuracy improved from -inf to 0.02779, saving model to logs/fit/20230411-191532/models/model.01-0.03.hdf5
# 225/225 [==============================] - 179s 771ms/step - loss: 4.1013 - categorical_accuracy: 0.4201 - val_loss: 5.0663 - val_categorical_accuracy: 0.0278 - lr: 0.0020
# Epoch 2/100
# 225/225 [==============================] - ETA: 0s - loss: 0.6377 - categorical_accuracy: 0.9019
# Epoch 2: val_categorical_accuracy improved from 0.02779 to 0.43418, saving model to logs/fit/20230411-191532/models/model.02-0.43.hdf5
# 225/225 [==============================] - 175s 777ms/step - loss: 0.6377 - categorical_accuracy: 0.9019 - val_loss: 2.1720 - val_categorical_accuracy: 0.4342 - lr: 0.0020
# Epoch 3/100
# 225/225 [==============================] - ETA: 0s - loss: 0.4139 - categorical_accuracy: 0.9400
# Epoch 3: val_categorical_accuracy improved from 0.43418 to 0.74436, saving model to logs/fit/20230411-191532/models/model.03-0.74.hdf5
# 225/225 [==============================] - 174s 775ms/step - loss: 0.4139 - categorical_accuracy: 0.9400 - val_loss: 0.9375 - val_categorical_accuracy: 0.7444 - lr: 0.0020
# Epoch 4/100
# 225/225 [==============================] - ETA: 0s - loss: 0.3410 - categorical_accuracy: 0.9519
# Epoch 4: val_categorical_accuracy improved from 0.74436 to 0.77214, saving model to logs/fit/20230411-191532/models/model.04-0.77.hdf5
# 225/225 [==============================] - 173s 771ms/step - loss: 0.3410 - categorical_accuracy: 0.9519 - val_loss: 1.0748 - val_categorical_accuracy: 0.7721 - lr: 0.0020
# Epoch 5/100
# 225/225 [==============================] - ETA: 0s - loss: 0.3022 - categorical_accuracy: 0.9582
# Epoch 5: val_categorical_accuracy improved from 0.77214 to 0.86419, saving model to logs/fit/20230411-191532/models/model.05-0.86.hdf5
# 225/225 [==============================] - 173s 771ms/step - loss: 0.3022 - categorical_accuracy: 0.9582 - val_loss: 0.6383 - val_categorical_accuracy: 0.8642 - lr: 0.0020
# Epoch 6/100
# 225/225 [==============================] - ETA: 0s - loss: 0.2687 - categorical_accuracy: 0.9650
# Epoch 6: val_categorical_accuracy improved from 0.86419 to 0.87253, saving model to logs/fit/20230411-191532/models/model.06-0.87.hdf5
# 225/225 [==============================] - 174s 772ms/step - loss: 0.2687 - categorical_accuracy: 0.9650 - val_loss: 0.5377 - val_categorical_accuracy: 0.8725 - lr: 0.0020
# Epoch 7/100
# 225/225 [==============================] - ETA: 0s - loss: 0.2646 - categorical_accuracy: 0.9649
# Epoch 7: val_categorical_accuracy did not improve from 0.87253
# 225/225 [==============================] - 174s 773ms/step - loss: 0.2646 - categorical_accuracy: 0.9649 - val_loss: 0.5857 - val_categorical_accuracy: 0.8579 - lr: 0.0020
# Epoch 8/100
# 225/225 [==============================] - ETA: 0s - loss: 0.2510 - categorical_accuracy: 0.9674
# Epoch 8: val_categorical_accuracy improved from 0.87253 to 0.88781, saving model to logs/fit/20230411-191532/models/model.08-0.89.hdf5
# 225/225 [==============================] - 175s 775ms/step - loss: 0.2510 - categorical_accuracy: 0.9674 - val_loss: 0.5016 - val_categorical_accuracy: 0.8878 - lr: 0.0020
# Epoch 9/100
# 225/225 [==============================] - ETA: 0s - loss: 0.2289 - categorical_accuracy: 0.9715
# Epoch 9: val_categorical_accuracy improved from 0.88781 to 0.91004, saving model to logs/fit/20230411-191532/models/model.09-0.91.hdf5
# 225/225 [==============================] - 173s 767ms/step - loss: 0.2289 - categorical_accuracy: 0.9715 - val_loss: 0.4223 - val_categorical_accuracy: 0.9100 - lr: 0.0020
# Epoch 10/100
# 225/225 [==============================] - ETA: 0s - loss: 0.2279 - categorical_accuracy: 0.9707
# Epoch 10: val_categorical_accuracy improved from 0.91004 to 0.91073, saving model to logs/fit/20230411-191532/models/model.10-0.91.hdf5
# 225/225 [==============================] - 173s 771ms/step - loss: 0.2279 - categorical_accuracy: 0.9707 - val_loss: 0.4315 - val_categorical_accuracy: 0.9107 - lr: 0.0020
# Epoch 11/100
# 225/225 [==============================] - ETA: 0s - loss: 0.
100
# 225/225 [==============================] - ETA: 0s - loss: 0.0393 - categorical_accuracy: 0.9962
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 38: val_categorical_accuracy did not improve from 0.98159
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0393 - categorical_accuracy: 0.9962 - val_loss: 0.0935 - val_categorical_accuracy: 0.9764 - lr: 6.2500e-05
# Epoch 39/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0370 - categorical_accuracy: 0.9968
# Epoch 39: val_categorical_accuracy did not improve from 0.98159
# 225/225 [==============================] - 175s 776ms/step - loss: 0.0370 - categorical_accuracy: 0.9968 - val_loss: 0.0977 - val_categorical_accuracy: 0.9729 - lr: 3.1250e-05
# Epoch 40/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0363 - categorical_accuracy: 0.9971
# Epoch 40: val_categorical_accuracy improved from 0.98159 to 0.98645, saving model to logs/fit/20230411-191532/models/model.40-0.99.hdf5
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0363 - categorical_accuracy: 0.9971 - val_loss: 0.0661 - val_categorical_accuracy: 0.9865 - lr: 3.1250e-05
# Epoch 41/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0361 - categorical_accuracy: 0.9971
# Epoch 41: val_categorical_accuracy did not improve from 0.98645
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0361 - categorical_accuracy: 0.9971 - val_loss: 0.0981 - val_categorical_accuracy: 0.9739 - lr: 3.1250e-05
# Epoch 42/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0360 - categorical_accuracy: 0.9970
# Epoch 42: val_categorical_accuracy did not improve from 0.98645
# 225/225 [==============================] - 174s 773ms/step - loss: 0.0360 - categorical_accuracy: 0.9970 - val_loss: 0.1006 - val_categorical_accuracy: 0.9729 - lr: 3.1250e-05
# Epoch 43/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0360 - categorical_accuracy: 0.9969
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 43: val_categorical_accuracy did not improve from 0.98645
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0360 - categorical_accuracy: 0.9969 - val_loss: 0.0900 - val_categorical_accuracy: 0.9764 - lr: 3.1250e-05
# Epoch 44/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0350 - categorical_accuracy: 0.9973
# Epoch 44: val_categorical_accuracy did not improve from 0.98645
# 225/225 [==============================] - 174s 773ms/step - loss: 0.0350 - categorical_accuracy: 0.9973 - val_loss: 0.0784 - val_categorical_accuracy: 0.9795 - lr: 1.5625e-05
# Epoch 45/100
# ...
# Epoch 27/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0427 - categorical_accuracy: 0.9959
# Epoch 27: val_categorical_accuracy did not improve from 0.94060
# 225/225 [==============================] - 176s 780ms/step - loss: 0.0427 - categorical_accuracy: 0.9959 - val_loss: 0.4283 - val_categorical_accuracy: 0.8861 - lr: 2.5000e-04
# Epoch 28/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0416 - categorical_accuracy: 0.9960
# Epoch 28: val_categorical_accuracy improved from 0.94060 to 0.94616, saving model to logs/fit/20230412-040411/models/model.28-0.95.hdf5
# 225/225 [==============================] - 174s 773ms/step - loss: 0.0416 - categorical_accuracy: 0.9960 - val_loss: 0.1861 - val_categorical_accuracy: 0.9462 - lr: 2.5000e-04
# Epoch 29/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0396 - categorical_accuracy: 0.9959
# Epoch 29: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 175s 777ms/step - loss: 0.0396 - categorical_accuracy: 0.9959 - val_loss: 0.2486 - val_categorical_accuracy: 0.9260 - lr: 2.5000e-04
# Epoch 30/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0381 - categorical_accuracy: 0.9962
# Epoch 30: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 174s 771ms/step - loss: 0.0381 - categorical_accuracy: 0.9962 - val_loss: 0.2396 - val_categorical_accuracy: 0.9368 - lr: 2.5000e-04
# Epoch 31/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0393 - categorical_accuracy: 0.9958
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 31: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0393 - categorical_accuracy: 0.9958 - val_loss: 0.2240 - val_categorical_accuracy: 0.9309 - lr: 2.5000e-04
# Epoch 32/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0330 - categorical_accuracy: 0.9975
# Epoch 32: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 173s 771ms/step - loss: 0.0330 - categorical_accuracy: 0.9975 - val_loss: 0.2091 - val_categorical_accuracy: 0.9361 - lr: 1.2500e-04
# Epoch 33/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0314 - categorical_accuracy: 0.9973
# Epoch 33: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0314 - categorical_accuracy: 0.9973 - val_loss: 0.2574 - val_categorical_accuracy: 0.9333 - lr: 1.2500e-04
# Epoch 34/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0306 - categorical_accuracy: 0.9976
# Epoch 34: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 173s 771ms/step - loss: 0.0306 - categorical_accuracy: 0.9976 - val_loss: 0.2486 - val_categorical_accuracy: 0.9302 - lr: 1.2500e-04
# Epoch 35/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0292 - categorical_accuracy: 0.9977
# Epoch 35: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0292 - categorical_accuracy: 0.9977 - val_loss: 0.2055 - val_categorical_accuracy: 0.9416 - lr: 1.2500e-04
# Epoch 36/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0293 - categorical_accuracy: 0.9973
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 36: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0293 - categorical_accuracy: 0.9973 - val_loss: 0.2876 - val_categorical_accuracy: 0.9291 - lr: 1.2500e-04
# Epoch 37/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0264 - categorical_accuracy: 0.9982
# Epoch 37: val_categorical_accuracy did not improve from 0.94616
# 225/225 [==============================] - 175s 776ms/step - loss: 0.0264 - categorical_accuracy: 0.9982 - val_loss: 0.2215 - val_categorical_accuracy: 0.9437 - lr: 6.2500e-05
# Epoch 38/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0257 - categorical_accuracy: 0.9982
# Epoch 38: val_categorical_accuracy improved from 0.94616 to 0.94755, saving model to logs/fit/20230412-040411/models/model.38-0.95.hdf5
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0257 - categorical_accuracy: 0.9982 - val_loss: 0.1909 - val_categorical_accuracy: 0.9476 - lr: 6.2500e-05
# Epoch 39/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0252 - categorical_accuracy: 0.9979
# Epoch 39: val_categorical_accuracy improved from 0.94755 to 0.95068, saving model to logs/fit/20230412-040411/models/model.39-0.95.hdf5
# 225/225 [==============================] - 173s 770ms/step - loss: 0.0252 - categorical_accuracy: 0.9979 - val_loss: 0.1583 - val_categorical_accuracy: 0.9507 - lr: 6.2500e-05
# Epoch 40/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0245 - categorical_accuracy: 0.9982
# Epoch 40: val_categorical_accuracy did not improve from 0.95068
# 225/225 [==============================] - 173s 769ms/step - loss: 0.0245 - categorical_accuracy: 0.9982 - val_loss: 0.2128 - val_categorical_accuracy: 0.9361 - lr: 6.2500e-05
# Epoch 41/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0250 - categorical_accuracy: 0.9979
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 41: val_categorical_accuracy did not improve from 0.95068
# 225/225 [==============================] - 175s 776ms/step - loss: 0.0250 - categorical_accuracy: 0.9979 - val_loss: 0.1949 - val_categorical_accuracy: 0.9316 - lr: 6.2500e-05
# Epoch 42/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0235 - categorical_accuracy: 0.9981
# Epoch 42: val_categorical_accuracy did not improve from 0.95068
# 225/225 [==============================] - 174s 773ms/step - loss: 0.0235 - categorical_accuracy: 0.9981 - val_loss: 0.1542 - val_categorical_accuracy: 0.9507 - lr: 3.1250e-05
# Epoch 43/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0230 - categorical_accuracy: 0.9984
# Epoch 43: val_categorical_accuracy improved from 0.95068 to 0.95589, saving model to logs/fit/20230412-040411/models/model.43-0.96.hdf5
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0230 - categorical_accuracy: 0.9984 - val_loss: 0.1634 - val_categorical_accuracy: 0.9559 - lr: 3.1250e-05
# Epoch 44/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0225 - categorical_accuracy: 0.9984
# Epoch 44: val_categorical_accuracy did not improve from 0.95589
# 225/225 [==============================] - 173s 768ms/step - loss: 0.0225 - categorical_accuracy: 0.9984 - val_loss: 0.1720 - val_categorical_accuracy: 0.9486 - lr: 3.1250e-05
# Epoch 45/100
# 225/225 [==============================] - ETA: 0s - loss: 0.
val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 175s 776ms/step - loss: 0.0203 - categorical_accuracy: 0.9989 - val_loss: 0.1492 - val_categorical_accuracy: 0.9542 - lr: 1.0000e-06
# Epoch 61/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0204 - categorical_accuracy: 0.9990
# Epoch 61: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0204 - categorical_accuracy: 0.9990 - val_loss: 0.1487 - val_categorical_accuracy: 0.9552 - lr: 1.0000e-06
# Epoch 62/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0205 - categorical_accuracy: 0.9988
# Epoch 62: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 179s 794ms/step - loss: 0.0205 - categorical_accuracy: 0.9988 - val_loss: 0.1448 - val_categorical_accuracy: 0.9559 - lr: 1.0000e-06
# Epoch 63/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0201 - categorical_accuracy: 0.9990
# Epoch 63: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0201 - categorical_accuracy: 0.9990 - val_loss: 0.1487 - val_categorical_accuracy: 0.9545 - lr: 1.0000e-06
# Epoch 64/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0207 - categorical_accuracy: 0.9988
# Epoch 64: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 175s 777ms/step - loss: 0.0207 - categorical_accuracy: 0.9988 - val_loss: 0.1518 - val_categorical_accuracy: 0.9538 - lr: 1.0000e-06
# Epoch 65/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0204 - categorical_accuracy: 0.9987
# Epoch 65: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 174s 775ms/step - loss: 0.0204 - categorical_accuracy: 0.9987 - val_loss: 0.1484 - val_categorical_accuracy: 0.9545 - lr: 1.0000e-06
# Epoch 66/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0203 - categorical_accuracy: 0.9988
# Epoch 66: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 174s 774ms/step - loss: 0.0203 - categorical_accuracy: 0.9988 - val_loss: 0.1484 - val_categorical_accuracy: 0.9545 - lr: 1.0000e-06
# Epoch 67/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0203 - categorical_accuracy: 0.9986
# Epoch 67: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 173s 771ms/step - loss: 0.0203 - categorical_accuracy: 0.9986 - val_loss: 0.1439 - val_categorical_accuracy: 0.9555 - lr: 1.0000e-06
# Epoch 68/100
# 225/225 [==============================] - ETA: 0s - loss: 0.0212 - categorical_accuracy: 0.9984Restoring model weights from the end of the best epoch: 61.
#
# Epoch 68: val_categorical_accuracy did not improve from 0.95658
# 225/225 [==============================] - 174s 772ms/step - loss: 0.0212 - categorical_accuracy: 0.9984 - val_loss: 0.1457 - val_categorical_accuracy: 0.9555 - lr: 1.0000e-06
# Epoch 68: early stopping
# 0.9565821290016174
# 360/360 [==============================] - 19s 51ms/step

# %%
# CONFUSION MATRIX


y_test_class = [oh_dict[i] for i in np.concatenate(y_int_test_class)]
y_pred_class=[oh_dict[i] for i in np.concatenate(y_int_pred_class)]
confusion_mat = confusion_matrix(y_test_class, y_pred_class, labels=list(sign_types_dict.keys()))
plt.imshow(confusion_mat, cmap=plt.cm.Blues)
plt.title('Confusion matrix')
plt.colorbar()
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.xticks([cl for cl in range(num_classes)], sign_types_dict.keys())
plt.yticks([cl for cl in range(num_classes)], sign_types_dict.keys())
plt.show()

df_cm = pd.DataFrame(confusion_mat, index=list(sign_types_dict.keys()), columns=list(sign_types_dict.keys()))
cmap = 'PuRd'
#pp_matrix(df_cm, cmap=cmap)

# tf.math.confusion_matrix(Y_test,y_pred)
# #%%
# # ROC PLOT
# fpr = {}
# tpr = {}
# roc_auc = {}
#
# for i in range(3):
#     fpr[i], tpr[i], _ = roc_curve(Y_test[:, i], y_pred[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])
#
# plt.figure()
# for i in range(3):
#     plt.plot(fpr[i], tpr[i], label='ROC curve for class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.0])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC curves for all classes')
# plt.legend(loc="lower right")
# plt.show()

# %%
np.average(test_acc_list)
# Out:
# 0.963379418849945
